# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections
from collections import Counter
import os

# %% [markdown]
# # 3. Слоговая структура и попарное сравнение языков
# В этой части мы посмотрим на слоговую структуру с опорой на первоначальную базу данных (df) - тем самым сделаем выводы о слогах в отдельных языках. Но что важнее, мы введем попарное сравнение языков и будем смотреть, какие слоги в какие чаще переходит - это отражает фонетические процессы в родственных языках.
#
# ### 3.1. От фонем к CV-представлениям
# Для работы с LexStat, мы убрали дефисное деление звуков в транскрипции, поэтому чтобы привести звуки к записи вида CVCVCV, вернемся к фонемному составу языков.

# %%
# все звуки поделим на гласные и согласные

vwls = ['ẽ', 'ũ', 'ĩ', 'õ', 'ã', 'u', 'o', 'i', 'e', 'a']

cons = ['χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɢ', 'ɡ', 'ħ', 'z', 'x', 'w', 'tʃ', 'tɬ', 
        'ts', 't', 's', 'r', 'qχ', 'q', 'p', 'n', 'm', 'l', 'k', 'j', 'h', 'f', 'dʒ', 'dz', 'd', 'b']

# чтобы отдельно рассмотреть процессы, происходящие с r,l,m,n,w,j,b, не будем их заменять на C

cons_sans_rlmnwjb = ['χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɢ', 'ɡ', 'ħ', 'z', 'x', 'tʃ', 'tɬ', 
        'ts', 't', 's', 'qχ', 'q', 'p','k', 'h', 'f', 'dʒ', 'dz', 'd']

# %%
# фонемный состав языков отличается 
# (например, где-то есть звук "dʒ", а где-то это сочетание звуков "d" и "ʒ")

langs = {'akhv1239': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 'õ', 'ã', 'z', 'x', 
                      'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'q', 'p', 'o', 'n', 'm', 'l', 'k', 
                      'j', 'i', 'h', 'e', 'dʒ', 'd', 'b', 'a'], 
         
         'andi1255': ['χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɢ', 'ɡ', 'z', 'x', 'w', 'u', 'tʃ', 
                      'tɬ', 'ts', 't', 's', 'r', 'q', 'p', 'o', 'n', 'm', 'l', 'k', 'j', 'i', 
                      'h', 'e', 'dʒ', 'd', 'b', 'a'],
         
         'bagv1239': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 'õ', 'ã', 
                      'z', 'x', 'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'q', 'p', 'o', 
                      'n', 'm', 'l', 'k', 'j', 'i', 'h', 'e', 'dʒ', 'd', 'b', 'a'],
         
         'botl1242': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 
                      'õ', 'ã', 'z', 'x', 'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'q', 
                      'p', 'o', 'n', 'm', 'l', 'k', 'j', 'i', 'h', 'f', 'e', 'dʒ', 'd', 'b', 'a'],
         
         'cham1309': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 'õ', 'ã', 'z', 
                      'x', 'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'qχ', 'q', 'p', 'o', 'n', 
                      'm', 'l', 'k', 'j', 'i', 'h', 'e', 'dʒ', 'dz', 'd', 'b', 'a'],
         
         'ghod1238': ['χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 'ã', 'z', 'x', 
                      'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'q', 'p', 'o', 'n', 'm', 
                      'l', 'k', 'j', 'i', 'h', 'e', 'dʒ', 'd', 'b', 'a'],
         
         'kara1474': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 'õ', 
                      'ã', 'z', 'x', 'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'q', 'p', 
                      'o', 'n', 'm', 'l', 'k', 'j', 'i', 'h', 'e', 'd', 'b', 'a'],
         
         'tind1238': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɡ', 'ũ', 'ĩ', 'ħ', 
                      'õ', 'ã', 'z', 'x', 'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 
                      'q', 'p', 'o', 'n', 'm', 'l', 'k', 'j', 'i', 'h', 'e', 'dʒ', 'd', 'b', 'a'],
         
         'toki1238': ['ẽ', 'χ', 'ʕ', 'ʔ', 'ʒ', 'ʃ', 'ʁ', 'ɬ', 'ɢ', 'ɡ', 'ũ', 'ĩ', 'ħ', 
                      'ã', 'z', 'x', 'w', 'u', 'tʃ', 'tɬ', 'ts', 't', 's', 'r', 'q', 'p', 
                      'o', 'n', 'm', 'l', 'k', 'j', 'i', 'h', 'e', 'd', 'b', 'a']
        }

# %%
# для каждого языка разделим звуки на согласные и гласные

v = {'akhv1239': [], 'andi1255': [], 'bagv1239': [], 'botl1242': [], 'cham1309': [], 
     'ghod1238': [], 'kara1474': [], 'tind1238': [], 'toki1238': []}
c = {'akhv1239': [], 'andi1255': [], 'bagv1239': [], 'botl1242': [], 'cham1309': [], 
     'ghod1238': [], 'kara1474': [], 'tind1238': [], 'toki1238': []}
c_sans_rlmnwjb = {'akhv1239': [], 'andi1255': [], 'bagv1239': [], 'botl1242': [], 
                  'cham1309': [], 'ghod1238': [], 'kara1474': [], 'tind1238': [], 'toki1238': []}

for key in langs:
    for el in vwls:
        if el in langs[key]:
            v[key].append(el)
    for el in cons:
        if el in langs[key]:
            c[key].append(el)
    for el in cons_sans_rlmnwjb:
        if el in langs[key]:
            c_sans_rlmnwjb[key].append(el)

# %%
# ф-я, на вход которой подается строка s, словарь гласных V, словарь согласных C, язык l
# преобразует фонемную запись в представление CVCV

def letters_to_CV(s, V, C, l):
    s = s.replace("'", '')
    s = s.replace("ʷ", '')
    s = s.replace('ʲ','')
    s = s.replace('̃', '')
    s = s.replace('ː','')
    s = s.replace('ˌ','')

    for i in range(len(s)):
        flag = True
        for v in V[l]:
            if v in s and flag:
                s = s.replace(v, "V")
                flag = False
                break
        if flag:
            for c in C[l]:
                if c in s:
                    s = s.replace(c, "C")
                    break                
    return s

# %%
# ф-я, получающая на вход строку word вида CVCVCV
# делит ее на слоги

def s_to_syllables(word):
    vowels = []
    for i in range(len(word)):
        if word[i] == 'V':
            vowels.append(i)

    hyphens = collections.deque()
    for i in range(1, len(vowels)):
        a, b = vowels[i-1], vowels[i]
        if b - a == 1:
            hyphens.append(b)
        elif b - a == 2:
            hyphens.append(b - 1)
        else:
            hyphens.append(a + 2)

    res = ''
    for i in range(len(word)):
        if len(hyphens) and hyphens[0] == i:
            res += '-'
            hyphens.popleft()
        res += word[i]
    return res

# %% [markdown]
# ### 3.2. Общая информация
# Обратимся к первоначальной базе данных, чтобы вне контекста когнатов посмотреть на слоговые структуры в языках.

# %%
df = pd.read_csv('edited_andic_dicts.csv', sep=',')
df['meaning_ru'] = df.apply(lambda row: row['new_meaning_ru'] if pd.notnull(row['new_meaning_ru']) else row['meaning_ru'], axis=1)
df = df.drop_duplicates(subset=['ipa', 'meaning_ru', 'glottocode', 'bor'], keep='first')
df = df.dropna(subset=['ipa', 'meaning_ru'], how='any')

df['ipa'] = df['ipa'].apply(lambda x: x.replace('-', '') if isinstance(x, str) else x)
df['ipa'] = df['ipa'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else x)

# %%
# исследуем слоговую структуру

df['cv'] = df.apply(lambda row: s_to_syllables(letters_to_CV(row['ipa'], v, c, row['glottocode'])), axis=1)
df[['glottocode', 'ipa', 'cv']]
# Out:
#       glottocode          ipa              cv
# 0       akhv1239   ab'adatɬːi     V-CV-CVC-CV
# 1       akhv1239      ab'aʒʷe         V-CV-CV
# 2       akhv1239  abaʒ'urutɬa  V-CV-CV-CVC-CV
# 3       akhv1239  abaʒ'urutɬa  V-CV-CV-CVC-CV
# 4       akhv1239  abaʒ'urutɬa  V-CV-CV-CVC-CV
# ...          ...          ...             ...
# 81656   toki1238       baʃl'a          CVC-CV
# 81657   toki1238   besad'iril    CV-CV-CV-CVC
# 81658   toki1238       itʃ'ib          VC-CVC
# 81659   toki1238    itʃ'ik'al       VC-CV-CVC
# 81660   toki1238    χĩχiledu     CV-CV-CV-CV
#
# [81661 rows x 3 columns]

# %%
# используем ф-ии для выделения в CV-представлении df['cv'] всех слогов / первых слогов / последних слогов

def count_syllable_types(cv):
    syllables = cv.split('-')
    types = [s.split('-')[-1] for s in syllables]
    return types

def count_first_syllable_types(cv):
    first_syllable = cv.split('-')[0]
    first_type = first_syllable.split('-')[-1] if '-' in first_syllable else first_syllable
    return first_type

def count_last_syllable_types(cv):
    first_syllable = cv.split('-')[-1]
    first_type = first_syllable.split('-')[-1] if '-' in first_syllable else first_syllable
    return first_type

syllable_types = ['CV', 'CVC', 'CCV', 'V', 'VC', 'CCVC', 'CVCC', 'CCCV', 'CVCCC', 'CCVCC']

# %%
# посмотрим общую статистику по языкам

general_statistics = df.groupby('glottocode')['cv'].apply(lambda x: x.apply(count_syllable_types).explode().value_counts()).unstack(fill_value=0)
general_statistics = general_statistics.reindex(columns=syllable_types, fill_value=0)

general_statistics
# Out:
#                CV    CVC   CCV    V   VC  CCVC  CVCC  CCCV  CVCCC  CCVCC
# glottocode
# akhv1239    37113   5505  1442  953  329   231     4     0      0      0
# andi1255    13390   7710   718  364  462   567    13    13      3      0
# bagv1239    18342  11113   825  781  562   628   205    11      4     17
# botl1242    27484  15671  1005  876  969   710   383    18      6     16
# cham1309    16048   5865   655  834  553   354   280    24     21     24
# ghod1238    13854   4349   391  414  374   212    17     1      0      0
# kara1474    12013   4772   458  343  189   206    90     1      7      1
# tind1238    21471   7936   606  922  260   366    10     1      0      0
# toki1238       10      6     0    1    2     0     0     0      0      0

# %%
directory = 'output_html/about_whole_data/'
os.makedirs(directory, exist_ok=True)

general_stat_html = general_statistics.to_html()
with open('output_html/about_whole_data/general_stat_html.html', 'w') as f:
    f.write(general_stat_html)

# %%
# посмотрим статистику по последнему слогу

last_syl_statistics = df.groupby('glottocode')['cv'].apply(lambda x: x.apply(count_last_syllable_types).value_counts()).unstack(fill_value=0)
last_syl_statistics = last_syl_statistics.reindex(columns=syllable_types, fill_value=0)

last_syl_statistics
# Out:
#                CV   CVC  CCV   V  VC  CCVC  CVCC  CCCV  CVCCC  CCVCC
# glottocode
# akhv1239    12717    22   41   4   0     0     4     0      0      0
# andi1255     5937  2263  186   5  24    87    13     1      3      0
# bagv1239     4588  5549   62  26  72   282   205     0      4     17
# botl1242     7980  7670  213  48  47   132   383    11      6     16
# cham1309     5954  2498  198  14  89   130   280     4     21     24
# ghod1238     5003  1583   75  31  14    26    17     1      0      0
# kara1474     3787  2492   53  11   9    43    90     0      7      1
# tind1238     6103  4273   55   6  18    30    10     1      0      0
# toki1238        2     4    0   0   0     0     0     0      0      0

# %%
last_syl_stat_html = last_syl_statistics.to_html()
with open('output_html/about_whole_data/last_syl_stat_html.html', 'w') as f:
    f.write(last_syl_stat_html)

# %%
# посмотрим статистику по первому слогу

first_syl_statistics = df.groupby('glottocode')['cv'].apply(lambda x: x.apply(count_first_syllable_types).value_counts()).unstack(fill_value=0)
first_syl_statistics = first_syl_statistics.reindex(columns=syllable_types, fill_value=0)

first_syl_statistics
# Out:
#               CV   CVC   CCV    V   VC  CCVC  CVCC  CCCV  CVCCC  CCVCC
# glottocode
# akhv1239    8630  1262  1424  912  329   231     0     0      0      0
# andi1255    3657  3218   412  342  451   406     8    12      3      0
# bagv1239    5507  3248   444  601  521   365   119     0      3     10
# botl1242    8350  5408   507  702  891   563    88     1      3      9
# cham1309    4616  2528   311  809  530   285   112     0     16     16
# ghod1238    3843  1883   218  291  319   189     7     1      0      0
# kara1474    3876  1620   342  298  175   159    21     1      1      0
# tind1238    6555  2074   465  823  236   335     8     1      0      0
# toki1238       2     1     0    1    2     0     0     0      0      0

# %%
first_syl_stat_html = first_syl_statistics.to_html()
with open('output_html/about_whole_data/first_syl_stat_html.html', 'w') as f:
    f.write(first_syl_stat_html)

# %% [markdown]
# ### 3.3. БД с когнатами

# %%
# достанем из первоначальной базы данных значения заимствований

bor_dict = {}
for ind in df.index:
    if df['bor'][ind] == 1:
        if df['glottocode'][ind] not in bor_dict:
            bor_dict[df['glottocode'][ind]] = []
        bor_dict[df['glottocode'][ind]].append(df['ipa'][ind])
bor_dict
# Out:
# {'akhv1239': ["ab'adatɬːi",
#   "aw'arak'e",
#   "aw'arija",
#   "aw'asi",
#   "ad'a",
#   "ad'a",
#   "adaɡʷ'edabe",
#   "adaɡʷik'abe",
#   "ad'aq'ːedabe",
#   "ad'atɬːi",
#   "ad'aqːati",
#   "ad'aqːati",
#   "ad'ija",
#   "adikal'o",
#   "aʒ'ana",
#   "aʒ'a",
#   "az'aho",
#   "az'azaroda",
#   "azar'o",
#   "azar'oda",
#   "azar'otʃ'e",
#   "azerbedʒ'ano",
#   "azib'a",
#   "azb'a",
#   "aj'ati",
#   "atɬ'ː'udaʔazaro",
#   "atɬ'ːʷ'aːzaroda",
#   "al'ati",
#   "al'ati",
#   "al'atiq'ːe",
#   "alː'ahi",
#   "alː'a",
#   "alː'ahibet'ẽha",
#   "al'ipa",
#   "al'ipi",
#   "alpaw'iti",
#   "am'anate",
#   "amasː'e",
#   'amerikãtso',
#   "am'ini",
#   "am'ini",
#   "amː'a",
#   "apar'ak'e",
#   "apits'eri",
#   "ap'azar'oda",
#   "arm'eno",
#   "art'eli",
#   "as'a",
#   "as'i",
#   "as'i",
#   'asːalamuʕalẽku',
#   'asːalaʕaleku',
#   'asːetina',
#   'asːetino',
#   "asːk'a",
#   "asːt'awpirulːa",
#   "ast'owpirulːa",
#   "aχ'i",
#   "aχiɬ'e",
#   "aχiɬːiɡ'e",
#   "aχiɬːiɡel'a",
#   "aχir'ati",
#   "aχ'iqːa",
#   "aħʷ'aħa",
#   "aħim'aq'ːedabe",
#   "aħm'aq'ːedabe",
#   "aħim'aq'ːe",
#   "aħmaq'ːe",
#   "aħim'aq'ːɬilaje",
#   "aħm'aq'ːɬila",
#   "aħim'aq'ːɬiloːrutɬa",
#   "aħm'aq'ːɬiloːrutɬa",
#   "ãd'e",
#   "ãd'e",
#   "ãd'eːɬe",
#   "ãd'eːɬe",
#   "ãd'eːɬe",
#   "b'adraʒa",
#   "b'adraʒa",
#   "baz'a",
#   "baz'a",
#   "baz'aʒo",
#   "baz'aʒo",
#   "baz'aħaq'ːi",
#   "baj'adabe",
#   "baj'adabe",
#   "bak'a",
#   "b'akabaka",
#   "bak'ala",
#   "bark'ala",
#   "b'akatɬːi",
#   "b'akatɬːibe",
#   "b'ake",
#   "bak'urutɬa",
#   "b'alũ",
#   "b'alũ",
#   "batuʃː'ik'a",
#   "ʕurusabatuʃː'ik'a",
#   "baχ'idabe",
#   "baχ'idabe",
#   "baχ'iɬilaje",
#   "baχ'iɬilaje",
#   "baχ'iɬiloːrutɬa",
#   "baχ'iɬiloːrutɬa",
#   "baχːaj'e",
#   "baʃk'iro",
#   "belar'uso",
#   "b'eːraqːe",
#   "bid'ira",
#   "bik'a",
#   "bik'a",
#   "bik'a",
#   "bit'u",
#   "b'ozi",
#   "boq'ʷ'aːzaro",
#   "boq'ʷ'aːzaroda",
#   "boq''odaːzaro",
#   "b'otʃika",
#   "bur'o",
#   "b'uts'udi",
#   "wab'aʕa",
#   "wab'aʕa",
#   "waʕz'a",
#   "waʕz'a",
#   "waʕiz'a",
#   "waʕiz'a",
#   "wak'i",
#   "waq'ːh'u",
#   "waq'ː'u",
#   "w'alabilːaːhi",
#   "w'alahibilːahi",
#   "wal'i",
#   "wal'i",
#   "wal'eti",
#   "wasʷ'asi",
#   "wasʷ'asila",
#   "wasʷ'asila",
#   "wasʷ'asiloːrutɬa",
#   "wasʷ'asiloːt'orutɬa",
#   "was'iɡate",
#   "was'iɡate",
#   "was'ijate",
#   "was'ijate",
#   "mas'ijate",
#   "mas'ijate",
#   "mas'iɡate",
#   "mas'iɡate",
#   "w'at'a",
#   "w'aħiawarak'e",
#   "w'aħiawarak'e",
#   "waħʃ'idabe",
#   "waħʃ'iɬila",
#   "waħʃ'iɬilaje",
#   "waħʃ'iɬiloːrutɬa",
#   "w'aɡu",
#   "ɡ'azi",
#   "ɡalip'e",
#   "ɡ'ara",
#   "ɡ'ara",
#   "ɡuʒ'a",
#   "ɡuʒ'aːdi",
#   'ʁaza',
#   'ʁaza',
#   "ʁaz'awate",
#   "ʁal'at'i",
#   "ʁap'uɬilaje",
#   "ʁap'uɬilaje",
#   "ʁap'uɬiloːrutɬa",
#   "ʁap'uɬiloːrutɬa",
#   "ʁar'abaʃːi",
#   "ʁar'abaʃːi",
#   "haw'a",
#   "haw'a",
#   "h'amaʁe",
#   'pana',
#   "hʷan'ari",
#   "pan'ari",
#   "hʷan'eːra",
#   "pan'eːra",
#   "hʷar'izadabe",
#   "par'izadabe",
#   "hʷ'eːda",
#   "p'eːda",
#   "huʒ'umi",
#   "h'una",
#   "h'una",
#   "h'una",
#   "h'una",
#   "h'una",
#   "ʕabas'e",
#   "ʕad'atabe",
#   "ʕad'ataq'ːerotɬːi",
#   "ʕad'ataɬe",
#   "ʕ'adilo",
#   "ʕ'adilomizã",
#   "ʕ'adiloniza",
#   "ʕadʒ'ara",
#   "ʕaʒ'a",
#   "ʕaʒ'ala",
#   "ʕadʒ'arotɬ'e",
#   "ʕaʒ'uʒi",
#   "ʕaʒ'uʒimaʒuʒi",
#   "ʕaʒ'uʒimaʒuʒi",
#   "ʕaz'a",
#   "ʕaz'a",
#   "ʕaz'a",
#   "ʕaz'a",
#   'ʕazanalːahi',
#   "ʕaz'i",
#   "ʕ'akisːa",
#   "ʕ'aksːa",
#   "ʕ'aq'ːi",
#   "ʕaq'ː'uba",
#   "ʕaq'ː'uba",
#   "ʕaq'ː'uba",
#   "ʕaq'ː'ubaq'ːʷaraɬe",
#   "ʕal'amate",
#   "ʕal'amate",
#   "ʕ'alaχe",
#   "ʕ'alaχe",
#   "ʕal'i",
#   "ʕalim'aːk'ːa",
#   "ʕalim'eːk'ʷa",
#   "ʕamalatʃ'e",
#   "ʕamaχas'ijate",
#   "ʕamaχas'ijate",
#   "ʕ'ara",
#   "ʕarab'ija",
#   "ʕarab'ija",
#   "ʕar'abo",
#   "ʕar'ada",
#   "ʕar'aq'ːi",
#   "ʕar'aʃːimeːda",
#   "ʕar'aʃːimeːda",
#   "ʕasː'idabe",
#   "ʕat'l'asːi",
#   "ʕ'aq'ːra",
#   "ʕ'aq'ːra",
#   "ʕ'aq'ːira",
#   "ʕ'aq'ːira",
#   "ʕeːrapul'a",
#   "ʕ'idaːtɬːi",
#   "ʕ'idaːtɬːibe",
#   "ʕilː'a",
#   "ʕir'aq'ːetɬːiwe",
#   "ʕir'aq'ːetɬːije",
#   "ʕir'aq'ːo",
#   "ʕ'uzu",
#   "ʕ'umi",
#   "ʕur'usa",
#   "ʕur'usaɬːiqːe",
#   "daʕb'adilaje",
#   "daʕb'adiloːrutɬa",
#   "daʕb'adiloːrutɬa",
#   "d'aʕba",
#   "d'aʕiba",
#   "daʒʷ'ale",
#   "daʒʷ'ale",
#   "da'ida",
#   "da'idasːe",
#   "da'iɬilaje",
#   "dar'abaza",
#   "dar'abaza",
#   "dar'aʒa",
#   "dar'aʒa",
#   "dar'aʒa",
#   "dar'u",
#   "dar'u",
#   "dar'udama",
#   "darutɬː'i",
#   "darutɬː'i",
#   "dar'usaba",
#   "dar'usaba",
#   "dar'usaba",
#   "d'aska",
#   "d'ibi",
#   "d'ibi",
#   "d'iwa",
#   'dĩwa',
#   "d'iwa",
#   "d'iwa",
#   'dĩwa',
#   'dĩwa',
#   "din'i",
#   'dĩ',
#   "duʕ'a",
#   "duʕaʕ'ami",
#   "dun'a",
#   "dun'a",
#   "dun'a",
#   "dun'abatɬ'aɬːiɡe",
#   "dun'aʕala",
#   "dun'aʕala",
#   "dur'usadabe",
#   "dur'usadabe",
#   "dʒ'awa",
#   "dʒ'awa",
#   "dʒaz'a",
#   "dʒ'azuma",
#   "dʒ'azuma",
#   "dʒam'aʕaɬe",
#   "dʒan'aza",
#   "dʒan'aza",
#   "dʒan'aza",
#   "ʒan'aza",
#   "ʒan'aza",
#   "ʒan'aza",
#   "dʒan'aħi",
#   "dʒasː'usːi",
#   "dʒasː'usːi",
#   'dʒã',
#   "dʒ'inara",
#   "dʒ'ida",
#   "dʒ'uzi",
#   "ʒuh'ut'a",
#   "ʒuh'ut'o",
#   "z'awa",
#   "zah'idabe",
#   "zah'iɬilaje",
#   "zah'iɬiloːrutɬa",
#   "z'ahiro",
#   "z'ahirozaq'ːu",
#   "z'ahirotɬːi",
#   "zahrum'a",
#   "zahrum'a",
#   "zaʕ'idabe",
#   "zaʕ'idabe",
#   "zaʕ'idabe",
#   "zaʕ'iɬilaje",
#   "zaʕ'iɬiloːrutɬa",
#   "zaʕ'iɬiloːrutɬa",
#   "zaʕ'iɬiloːrutɬa",
#   "zaʕ'iɬiloːrutɬa",
#   "zak'aʕate",
#   "zak'ati",
#   "z'akisːi",
#   "z'alĩ",
#   "z'ama",
#   "zam'azamaɬːiɡe",
#   "z'ara",
#   "zaħʷ'aɬilajeːhe",
#   "zaħʷ'aɬilaje",
#   "zaħʷ'atadabe",
#   "zaħʷ'atadabe",
#   "zaħʷ'atadabe",
#   "zʷanok'i",
#   "zij'arate",
#   "z'ikira",
#   "zuz'umaːtɬːi",
#   "z'umi",
#   "z'umi",
#   "zum'iqːa",
#   "id'aːra",
#   "iʒ'aːra",
#   "iziraʕ'ili",
#   "iziraʕ'ili",
#   "ij'aħinamusi",
#   "ilis'e",
#   "im'a",
#   "im'a",
#   'imaɡʷedabe',
#   'imãɡʷedabe',
#   "im'ama",
#   "im'amadi",
#   'isibuxːidawe',
#   'isibuxːidaje',
#   "isil'a",
#   "isil'a",
#   "ĩs'a",
#   "isp'itʃka",
#   "iχtil'ati",
#   "iʃ'aːra",
#   "iʃ'aːra",
#   "iʃk'api",
#   "ĩɡil'isa",
#   "ĩɡil'isa",
#   "ĩɡil'iso",
#   "ĩtɬː'idaːzaro",
#   "ĩsan'ijate",
#   'ja',
#   'ja',
#   "j'abu",
#   "jaq'ː'uti",
#   "j'ala",
#   "jar'aʁi",
#   "jas'i",
#   "jas'e",
#   "jaʃː'iki",
#   "j'aʃːuri",
#   'jubka',
#   "kabard'ina",
#   "kabard'ino",
#   "kaʁ'a",
#   "kaʁ'a",
#   "kaʁ'a",
#   "kaʁ'a",
#   "kaʁ'a",
#   "kaʁaq'ːetʃ''u",
#   "kahrum'a",
#   "kah'udabe",
#   "kah'udabe",
#   "kah'uɬe",
#   "kahuɬ'urutɬa",
#   "kahur'ek'ʷa",
#   "kaz'ijate",
#   "kaz'eːte",
#   'kalã',
#   'kalima',
#   "kalm'ika",
#   "kalm'iko",
#   "k'amidabe",
#   "k'amidabe",
#   "k'amilaje",
#   "k'amilaje",
#   "k'amiloːrutɬa",
#   "k'amiloːrutɬa",
#   "kam'iɬilaje",
#   "kam'iɬiloːrutɬa",
#   "kap'arate",
#   "kar'awate",
#   "kar'eːtsːe",
#   "kar'eːtsːe",
#   "kareːtsː'o",
#   "kas'ara",
#   "kast'u",
#   "kast'u",
#   'katuʃːi',
#   'katuʃka',
#   "kaʃ'iʃi",
#   'kãtoːra',
#   "kem'eti",
#   "kep'etʃi",
#   "kip'itʃi",
#   "k'epi",
#   "k'epi",
#   "k'eto",
#   "k'eto",
#   "kil'o",
#   "kin'iʃːik'a",
#   "k'irʕali",
#   "k'iriʕali",
#   "kir'imdiʃːi",
#   "kit'ajetsːi",
#   "kit'ajetsːi",
#   "kit'ajtsːo",
#   "kit'ajtsːolobe",
#   'kitajeːtɬːi',
#   "kom'oki",
#   "kom'oki",
#   "k'urpa",
#   "q'ːab'iħadabe",
#   "q'ːab'iħadabe",
#   "q'ːab'iħadabe",
#   "q'ːab'iħaːbe",
#   "q'ːab'iħaːbe",
#   "q'ːab'iħaːbe",
#   "q'ːab'iħiɡuje",
#   "q'ːab'iħiɡuje",
#   "q'ːab'iħiɡurutɬa",
#   "q'ːab'iħiɡurutɬa",
#   "q'ːab'iħɬilaje",
#   "q'ːab'iħɬilaje",
#   "q'ːab'iħɬilaje",
#   "q'ːab'iħɬiloːrutɬa",
#   "q'ːab'iħɬiloːrutɬa",
#   "q'ːab'uɡuje",
#   "q'ːab'uɡuje",
#   "q'ːab'uɡurutɬa",
#   "q'ːab'uɡurutɬa",
#   "q'ːab'udabe",
#   "q'ː'abuɬe",
#   "q'ː'abuɬe",
#   "q'ː'abuɬe",
#   "q'ːabuɬ'urutɬa",
#   "q'ːabuɬ'urutɬa",
#   "q'ːaʕ'ida",
#   "q'ːaʕ'ida",
#   "q'ːaʕ'ida",
#   "q'ːaʕ'ida",
#   "q'ːaʕ'ida",
#   "q'ː'eːda",
#   "q'ː'eːda",
#   "q'ː'eːda",
#   "q'ː'eːda",
#   "q'ː'eːda",
#   "q'ː'ada",
#   "q'ː'ada",
#   "q'ː'adiro",
#   "q'ː'adiro",
#   "q'ː'adro",
#   "q'ː'adro",
#   "q'ː'adiroq'ːimate",
#   "q'ː'adiroq'ːimate",
#   "q'ː'adiroq'ːimate",
#   "q'ː'adroq'ːimate",
#   "q'ː'adroq'ːimate",
#   "q'ː'adroq'ːimate",
#   "q'ː'adiroq'ːimateːtɬːi",
#   "q'ː'adiroq'ːimateːtɬːi",
#   "q'ː'adroq'ːimateːtɬːi",
#   "q'ː'adroq'ːimateːtɬːi",
#   "q'ː'adirotɬːi",
#   "q'ː'adirotɬːi",
#   "q'ː'adrotɬːi",
#   "q'ː'adrotɬːi",
#   "q'ːaʒ'ara",
#   "q'ːaʒ'ara",
#   "q'ːaʒ'aro",
#   "q'ː'azi",
#   "q'ː'aziɬːa",
#   "q'ːal'a",
#   "q'ːalã",
#   "q'ːan'atadabe",
#   "q'ːan'aːti",
#   "q'ːan'aʕati",
#   "q'ːan'atiɬiloːrutɬa",
#   "q'ːan'aʕaɬiloːrutɬa",
#   "q'ː'asːi",
#   "q'ː'asːi",
#   "q'ː'asːiɬːik'ena",
#   "q'ːat''ipa",
#   "q'ːat''ipa",
#   "q'ːat''ipa",
#   "q'ː'at'ra",
#   "q'ː'at'ira",
#   "q'ː'edaːtɬːi",
#   "q'ː'iba",
#   "q'ː'iba",
#   "q'ːij'aːmasːeʒo",
#   "q'ːij'aːmasːeq'ːo",
#   "q'ː'imate",
#   "q'ː'imate",
#   "q'ː'imate",
#   "q'ː'imate",
#   "q'ː'imateq'ːadiro",
#   "q'ː'imateq'ːadiro",
#   "q'ː'imateq'ːadiro",
#   "q'ː'imatitɬːi",
#   "q'ː'imatitɬːi",
#   "q'ːiʃːmiʃːi",
#   "q'ːiʃːmiʃːi",
#   "k'iʃːm'iʃːi",
#   "k'iʃːm'iʃːi",
#   "q'ː'ot'iq'ːada",
#   "q'ː'uwate",
#   "q'ː'uwate",
#   "q'ːuwat'itɬːi",
#   "q'ːumabiqːʷid'abeʒo",
#   "q'ːumeːqːʷid'aʒo",
#   "q'ː'urũʕa",
#   "q'ːũh'u",
#   "q'ːũh'u",
#   "tɬ''at'ame",
#   "k''ap'li",
#   "k''ap'ili",
#   "k''ap'ilitɬːi",
#   "k'ap'litɬːi",
#   "k'eb'ek'i",
#   "k''edaːzaro",
#   "l'aɡiri",
#   "laz'ateːtɬːi",
#   "laz'ateːtɬːi",
#   "laz'ati",
#   "laz'atiɬːiɡe",
#   "laz'atiɬːiɡe",
#   "l'aila",
#   "l'aila",
#   "l'amijalidi",
#   "lap'atka",
#   "lap'atika",
#   "lapsː'a",
#   "latar'e",
#   "latar'eja",
#   "lãp'a",
#   "lãp'a",
#   "l'apotʃka",
#   "lezɡ'ina",
#   "lezɡ'ina",
#   "lezɡ'ino",
#   "lez'eka",
#   "rez'eka",
#   "l'eːlatuq'ːadiro",
#   "l'itira",
#   "tɬaq'ːẽdoʔatʃ''adaʔazaro",
#   "tɬaq'ːẽdʷaːtʃ''adaːzaro",
#   "mah'ana",
#   "mah'ari",
#   "maʕ'ina",
#   "maʕ'ina",
#   "maʕ'ina",
#   "maʕ'ina",
#   "m'aʕna",
#   "m'aʕna",
#   "m'aʕna",
#   "m'aʕna",
#   "maʕ'iʃate",
#   "maʕ'iʃate",
#   "maʕ'iʃate",
#   "m'azi",
#   "m'aziha",
#   "m'aziha",
#   "m'aziha",
#   "m'aziha",
#   "m'akiro",
#   "m'akiro",
#   "m'akiro",
#   "m'akiro",
#   "m'akirotɬːi",
#   "m'akirotɬːi",
#   "m'akirotɬːi",
#   "maq'ː'ala",
#   "maq'ː'ala",
#   "maq'ːlat''isːi",
#   "maq'ːul'uʃːka",
#   "maq'ːul'uʃːka",
#   "m'ak'a",
#   "mal'eːke",
#   "m'alikimoːte",
#   "m'alikimoːte",
#   "m'alikimoːte",
#   "m'asːr'aʕate",
#   "masir'aʕate",
#   "masːqː'ara",
#   "masːqː'ara",
#   "maχːsː'ara",
#   "maχːsː'ara",
#   "masːqː'araq'ːʷĩ",
#   "masːqː'araq'ːʷĩ",
#   "maχːsː'araq'ːʷĩ",
#   "maχːsː'araq'ːʷĩ",
#   "maχm'ari",
#   "maχim'ari",
#   "m'aχːʃːi",
#   "maħir'uɡuje",
#   "maħir'uɬila",
#   "maħir'uɬilaje",
#   "maħir'uɬiloːrutɬa",
#   "maħiruɬilot'aje",
#   "maħir'uɬiloːt'urutɬa",
#   "m'aʃaːla",
#   "maʃh'uɬilaje",
#   "maʃh'uɬilaje",
#   "maʃh'u",
#   "maʃh'u",
#   "maʃh'uɬilaːdabe",
#   "maʃh'uɬilaːdabe",
#   "maʃh'uɬiloːrutɬa",
#   "maʃh'uɬiloːrutɬa",
#   "maʃ'ina",
#   "maʃt'a",
#   "maʃt'iti",
#   "mãz'i",
#   "maz'i",
#   "m'eːda",
#   "m'eːda",
#   "miz'a",
#   "miz'a",
#   "miz'aɬilaːdabe",
#   "miz'aɬilaje",
#   "miz'aɬiloːrutɬa",
#   "miz'aɬiloːt'aje",
#   "miz'aɬiloːt'urutɬa",
#   "miq''e",
#   "miq''e",
#   "mil'ati",
#   "mil'itsa",
#   "mil'itsa",
#   "milːĩ'o",
#   "milːĩ'o",
#   "min'uti",
#   "mis'a",
#   "mis'a",
#   "mis'aɬːa",
#   "mism'ila",
#   "bism'ila",
#   "m'itra",
#   "m'itra",
#   "m'itira",
#   "m'itira",
#   "m'etra",
#   "m'etra",
#   "miʃt'idabe",
#   "miʃt'iɬilaje",
#   "miʃt'iɬilaje",
#   "m'uhuro",
#   'muhru',
#   "muq'ːusadabe",
#   "m'uq'ːusaɬilaje",
#   "m'uq'ːusaɬilaje",
#   "muq'ːusaɬilorutɬa",
#   "muq'ːusaɬilorutɬa",
#   "muːl'idi",
#   "moːl'idi",
#   "munah'iq'ːe",
#   "munah'iq'ːe",
#   "mur'adi",
#   "mur'adi",
#   "musːʷ'aːdabe",
#   "musːʷ'aːɬe",
#   "musːʷ'aːɬe",
#   "musːʷ'aːɬunutɬa",
#   "musːʷ'aːɬunutɬa",
#   "musːʷ'anaːk'ːa",
#   "musːʷ'aneːk'ʷa",
#   "mutaʕ'ili",
#   "mutaʕ'iliɬe",
#   "mut''iʕadabe",
#   "mut''iʕadabe",
#   "mut''iʕadabe",
#   "mut'iʕiɡuje",
#   "mut'iʕiɡuje",
#   "mut''iʕiɡurutɬa",
#   "mut''iʕiɡurutɬa",
#   "mut''iʕiɡurutɬa",
#   "mut''iʕiɬilaje",
#   "mut''iʕiɬiloːrutɬa",
#   "mut''iʕiɬiloːrutɬa",
#   "muħk'aɡuːrutɬa",
#   "muħk'aɡuːrutɬa",
#   "muħk'aɡuːrutɬa",
#   "muħk'adabe",
#   "muħk'adabe",
#   "muħk'adabe",
#   "muħk'adabe",
#   "muħk'aɬilaje",
#   "muħk'aɬilaje",
#   "muħk'aɬilaje",
#   "muħk'aɬilaje",
#   "muħk'aɬilajeːhe",
#   "muħk'aɬilajeːhe",
#   "muħk'aɬilajeːhe",
#   "muħk'aɬilajeːhe",
#   "muħk'aɬilajeːhe",
#   "muħk'aɬiloːrutɬa",
#   "muħk'aɬiloːrutɬa",
#   "mũk'aʕaɬe",
#   "mũk'aʕaɬe",
#   'mũpaʕate',
#   'mũpaʕate',
#   "mũk'aʕaɬeɡotɬabe",
#   "mũk'aʕaɬeɡotɬabe",
#   'mũkaʕaɬeːtɬːi',
#   'mũkaʕaɬeːtɬːi',
#   "mũp'aʕateːtɬːi",
#   "mũp'aʕateːtɬːi",
#   "n'aʕana",
#   "nadʒasː'e",
#   "n'azimu",
#   "n'aq'ːiʃːe",
#   "n'aq'ːiʃːe",
#   "nal'uka",
#   "nam'usi",
#   "nam'usi",
#   "nam'usi",
#   "nam'useːtɬːi",
#   "nap'aq'ːa",
#   "n'asidabe",
#   "n'asilo",
#   "n'asilo",
#   "n'asilotũχu",
#   "n'asilotũχu",
#   "n'asilotuχu",
#   "n'asilotuχu",
#   "nas'iɬilaje",
#   "nas'iɬiloːrutɬa",
#   "n'ati",
#   "n'ati",
#   "naʔ'i",
#   "n'aʔiɬe",
#   "n'eɡra",
#   "n'eɡro",
#   "n'emtsa",
#   "n'emtso",
#   "n'iɡato",
#   "n'iɡato",
#   "n'ijato",
#   "n'ijato",
#   "n'iʕmate",
#   "n'iʕmate",
#   "n'iʕmate",
#   "n'ikili",
#   "niχː'ak'i",
#   'nuː',
#   "nuʁ'a",
#   "nuʁ'aːdi",
#   "n'uka",
#   "n'uka",
#   "n'uka",
#   "n'uħitɬːi",
#   'odiri',
#   "ok'oli",
#   "p'ahmu",
#   "p'ahmu",
#   "p'ahmu",
#   "paq'ː'i",
#   "paq'ː'iɬeːhe",
#   "pal'asːi",
#   "palat'in'o",
#   "palat'its'ːa",
#   "pal'uhãɬila",
#   "pal'uha",
#   'pamidoro',
#   "pan'adunija",
#   "papr'usːi",
#   "par'aznik'e",
#   "pas'ake",
#   "pas'ake",
#   "pas'ataːbe",
#   "pas'atiɡuje",
#   "pas'atiɡuje",
#   "pas'atiɡuje",
#   "pas'atiɡuje",
#   "pas'atiɡuje",
#   "pas'atiɡuje",
#   "pas'atiɡurutɬa",
#   "pas'atiɡurutɬa",
#   "pas'atiɡurutɬa",
#   "pas'atiɡurutɬa",
#   "pas'atiɡurutɬa",
#   "pas'atiɬilaje",
#   "pas'atiɬilaje",
#   "pas'atiɬilaje",
#   "pas'atiɬilaje",
#   "pas'atiɬilaje",
#   "pas'atiɬiloːrutɬa",
#   "pas'atiɬiloːrutɬa",
#   "pasː'iħadabe",
#   "pasː'iħadabe",
#   "pasː'iħadabe",
#   "pasː'iħiɬila",
#   "pasː'iħɬila",
#   "pasː'iħiɬilaje",
#   "pasː'iħɬilaje",
#   "pasː'iħiɬiloːrutɬa",
#   "pasː'iħɬiloːrutɬa",
#   "pat'ikadi",
#   "pat'u",
#   "patʃ'a",
#   "paʃl'iqːi",
#   "p'aːtiħa",
#   "p'erma",
#   "petʃ'ati",
#   "pitʃ'ati",
#   "p'etʃi",
#   "p'esija",
#   "pis'ija",
#   "pẽsian'eri",
#   "pidʒ'aki",
#   "p'ikiro",
#   "p'ikiro",
#   "p'ikiro",
#   "p'ikiro",
#   "p'ili",
#   "piriʕ'oni",
#   "piriʕ'oni",
#   "piriʕ'uni",
#   "piriʕ'uni",
#   "piskut'ura",
#   "p'ika",
#   "p'orma",
#   "p'orma",
#   "p'otʃi",
#   "purʒ'i",
#   "p'uti",
#   "p'utʃːi",
#   "razibik''urutɬa",
#   "razibik''urutɬa",
#   "raz'idabe",
#   "raz'idabe",
#   "raz'iɬilaje",
#   "raz'iɬiloːrutɬa",
#   "raz'iɬiloːrutɬa",
#   "raz'iɬiloːrutɬa",
#   "raz'irakidabe",
#   "raz'irakidabe",
#   "raz'irakiɬilaːje",
#   "raz'irakiɬiloːrutɬa",
#   "raħ'ateːtɬːi",
#   "raħ'ateːtɬːi",
#   "raħ'ateːtɬːi",
#   "raħ'ati",
#   "raħ'ati",
#   "raħim'ati",
#   "raħm'ati",
#   "r'aħimu",
#   "r'aħimu",
#   "r'aħimu",
#   "r'aħmu",
#   "r'aħmu",
#   "r'aħmu",
#   "raʃː'ote",
#   "rez'e",
#   "rez'e",
#   "lez'e",
#   "lez'e",
#   "rẽʔ'u",
#   "rẽʔ'u",
#   "r'iba",
#   "r'iziq'ːe",
#   "r'iziq'ːe",
#   "riʃːʷ'ate",
#   "riʃːʷ'ate",
#   "r'oʒoma",
#   "ruħak'en'asːe",
#   "ruħak'en'asːe",
#   "r'uħi",
#   "r'uħi",
#   "r'uħiħaɬːik'enasːe",
#   "r'uħitʃ'aɡoɬe",
#   "r'uħitʃ'aɡoɬila",
#   "sab'a",
#   "sab'a",
#   "sab'a",
#   "sab'a",
#   "s'aʁadabe",
#   "s'aʁaːbe",
#   "s'aʁsalamate",
#   "s'aʁsalamate",
#   "s'aʁsalamate",
#   'saχsalamate',
#   'saχsalamate',
#   'saχsalamate',
#   "s'ala",
#   "sal'akala",
#   "saχaw'atadabe",
#   "saχaw'atadabe",
#   'sã',
#   "sum'aqːi",
#   "s'urilaje",
#   'suχari',
#   'suχari',
#   'suʔa',
#   'suʔa',
#   'suʔa',
#   "sː'abu",
#   "sː'abu",
#   "sː'abu",
#   "sː'abudabe",
#   "sː'abudabe",
#   "sː'abuɬilaje",
#   "sː'abuɬilaje",
#   "sː'abuɬiloːrutɬa",
#   "sː'abuɬiloːrutɬa",
#   'sːabuʃːuku',
#   'sːabuʃːuku',
#   "sːaʕat'e",
#   "sːaʕat'e",
#   "sːaʕat'eleːde",
#   "sːaʕ'atiɡusːaʕatiɡa",
#   "sːad'aq'ːa",
#   "sːad'aq'ːa",
#   "sːad'aq'ːa",
#   "sːad'aq'ːa",
#   "sːaʒ'i",
#   "sːal'amatada",
#   "sːal'amatada",
#   "sːal'amatada",
#   "sːal'amatadabe",
#   "sːal'amatadabe",
#   "sːal'amatadabe",
#   "sːal'amatadabe",
#   "sːap'a",
#   "sːap'a",
#   "sːãh'u",
#   "sː'eːʁate",
#   "sːẽt'e",
#   "sːij'aħi",
#   "sːim'iti",
#   "sː'imitʃka",
#   'sːiħru',
#   'sːiħru',
#   "sː'iħrutʃi",
#   "sː'otiχːe",
#   "sː'uda",
#   "sː'udi",
#   "sː'udidĩwa",
#   "sː'udidĩwa",
#   "sː'udidĩwa",
#   "sːud'ija",
#   "sːuʒd'a",
#   "sː'unatadabe",
#   "sː'unatadabe",
#   "sː'unate",
#   "sː'unate",
#   "sːur'ati",
#   "sːur'ati",
#   "sːur'ati",
#   "sːur'ati",
#   "sːur'ati",
#   "sːur'ati",
#   "sːur'ati",
#   "sːur'ati",
#   "sː'urma",
#   "sː'uħmate",
#   "sː'uħimate",
#   "takr'aɡuje",
#   "takr'aɡurutɬa",
#   "taq'ː'ija",
#   "taq'ː'ija",
#   "taq'ːsː'iri",
#   ...],
#  'andi1255': ['abada',
#   'abadan',
#   'abadantɬi',
#   'abbareɡi',
#   'abbareɡi',
#   'abbasːi',
#   'abbasːi',
#   'abbasːi',
#   'abʒidu',
#   'abser',
#   'abtamabil',
#   'awlaqi',
#   'awlaqi',
#   'awlaqi',
#   'awrajti',
#   'awreɡi',
#   'ahʷal',
#   'ahʷalhal',
#   'ahlu',
#   'ahlu',
#   "ahmaq'i",
#   "ahmaq'ildːu",
#   'adab',
#   'adabloɡusːi',
#   'adam',
#   'adamɬilloɡusːi',
#   'adati',
#   'adlu',
#   'adlu',
#   'adʒaʔib',
#   'adʒaʔibdːu',
#   'adʒal',
#   'adʒal',
#   'adʒizi',
#   'adʒizildːu',
#   'azab',
#   'azbar',
#   'azizi',
#   'azizi',
#   'azizi',
#   'ajati',
#   'ajati',
#   'ajib',
#   'ajib',
#   'ajib',
#   'ajriplan',
#   'ajriplan',
#   'akber',
#   'akːatsi',
#   'aɢrab',
#   'alam',
#   'alam',
#   'alamati',
#   'alamati',
#   'alamati',
#   'alamatiɬir',
#   'alat',
#   'alat',
#   'alat',
#   'aldʒap',
#   'alim',
#   'alipi',
#   'alipi',
#   'allahi',
#   'allahilolo',
#   'allahiʃːujilzikol',
#   'almasːi',
#   'amal',
#   'amal',
#   'amal',
#   'amin',
#   'amma',
#   'amma',
#   'amru',
#   'amru',
#   'arada',
#   'arada',
#   'araɢi',
#   'aratsmajdan',
#   'arbaʔi',
#   'arzi',
#   'arzi',
#   'arʃːun',
#   'asar',
#   'asar',
#   'asir',
#   "ask'ar",
#   "ask'ar",
#   'aslu',
#   'asːi',
#   'asːi',
#   'asːildːu',
#   'asːildːu',
#   'atistati',
#   'aχir',
#   'aχir',
#   'aχirzaman',
#   'aχrati',
#   'aʃbazi',
#   'aʃdahu',
#   'aʃdahu',
#   "aʃiq'i",
#   "aʃiq'i",
#   "aʃiq'i",
#   'baha',
#   'baha',
#   'bahadur',
#   'bahadur',
#   'bahadur',
#   'bahadur',
#   'bahs',
#   'bajan',
#   'bajanɬir',
#   'bazar',
#   'bazar',
#   'bazarɡan',
#   'bajɡan',
#   'bajram',
#   'bajraqi',
#   'bajtulman',
#   'baliki',
#   'baliki',
#   'baliki',
#   'baliki',
#   'balon',
#   'banka',
#   'baluqi',
#   'baluqi',
#   'barka',
#   'barkajdu',
#   'barkalla',
#   'barkaloɡusːi',
#   'barkunnu',
#   'barχon',
#   'baχil',
#   'baχildːu',
#   "baʃluq'i",
#   "baʃmaq'i",
#   'bileti',
#   'billahi',
#   'bozi',
#   'bomba',
#   'buhtan',
#   'buhtan',
#   'buhtan',
#   'buhtan',
#   'buhtan',
#   'budun',
#   'bulbul',
#   'bulka',
#   'buluten',
#   'burow',
#   'burow',
#   'burow',
#   'burow',
#   'burow',
#   'butajlim',
#   'busːurman',
#   'wabatʃi',
#   'wahʃi',
#   'wahʃi',
#   'wakil',
#   "waq'pu",
#   'wali',
#   'waris',
#   'wasʷasi',
#   'wasʷasi',
#   "wat'an",
#   "wat'an",
#   'waʔaza',
#   'wollahi',
#   'ɡaram',
#   'ɡjawur',
#   'ɡjawur',
#   'ʁazawati',
#   'ʁazawati',
#   'ʁazawati',
#   "halat'i",
#   'ʁapuldːu',
#   'ʁara',
#   'ʁarabaʃːi',
#   'ʁarabaʃːi',
#   'ʁarabaʃːi',
#   'ɡaʔrb',
#   'ʁirmizi',
#   'ʁuluqi',
#   'hawa',
#   'hawa',
#   'hawa',
#   'hawa',
#   'hawla',
#   'hadʒati',
#   'hadʒatib',
#   'hadʒatiɬir',
#   'hadʒatunnu',
#   'hadʒatunnu',
#   'hadʒatχan',
#   'hadʒatχan',
#   'hajbati',
#   'hajbati',
#   'hajbati',
#   'hajbatildːu',
#   'hajbatildːu',
#   'hajbatildːu',
#   'hajwan',
#   'hajwan',
#   'haja',
#   'haja',
#   'hajran',
#   'hajrandːu',
#   'hajrandːu',
#   'hakim',
#   "haq'ib",
#   "haq'iq'ati",
#   "haq'ir",
#   "haq'irdːu",
#   'hal',
#   'halal',
#   'halal',
#   'halʁa',
#   'halʁa',
#   'halʁa',
#   'halim',
#   'halim',
#   'halimdːu',
#   'halimdːu',
#   'hamam',
#   'hammal',
#   'har',
#   'harakati',
#   'haram',
#   'haram',
#   'haram',
#   'haramdːu',
#   'haramzada',
#   'haramzada',
#   'haramzada',
#   'haramzada',
#   'harpi',
#   'hasrati',
#   'hasrati',
#   'hasrati',
#   'hasːil',
#   'hedʒi',
#   'hikmati',
#   'hikmatildːu',
#   'hilla',
#   'hilla',
#   'hillalima',
#   'hillalima',
#   'hillalima',
#   'hisab',
#   'howzi',
#   'howzi',
#   'howzi',
#   'hudʒa',
#   'hudʒa',
#   'hudʒra',
#   'hudʒum',
#   'hukmu',
#   'hukumati',
#   'hunar',
#   'hunar',
#   'hunar',
#   'hurmati',
#   'hurmati',
#   'hurullen',
#   'hurullen',
#   'huthut',
#   'daʔim',
#   'daʔim',
#   'daʔimdːu',
#   'dalil',
#   'daradʒa',
#   'daradʒa',
#   'daradʒa',
#   'daradʒa',
#   'daradʒa',
#   'darbiʃːi',
#   'dardi',
#   'darman',
#   'darsːi',
#   'daru',
#   'daʔba',
#   'daʔbadow',
#   'daʔbadunnu',
#   'daʔbaliʃa',
#   'dibir',
#   'diwan',
#   'diwan',
#   'diwan',
#   'din',
#   'duʁa',
#   'duʁa',
#   'dunjal',
#   'dunjal',
#   'dunjal',
#   'dunjaɬalam',
#   'dunjaɬalam',
#   'dunjaɬalam',
#   'durusi',
#   'durusi',
#   'durusildːu',
#   'durusildːu',
#   'dʒawab',
#   'dʒawhar',
#   'dʒahandaman',
#   'dʒahil',
#   'dʒahil',
#   'dʒahildːu',
#   'dʒahilɬir',
#   'dʒadal',
#   'dʒadal',
#   'dʒaza',
#   'dʒaza',
#   'dʒaza',
#   'dʒazmu',
#   'dʒajran',
#   'dʒajran',
#   'dʒajran',
#   'dʒajran',
#   'dʒajran',
#   'dʒan',
#   'dʒan',
#   'dʒan',
#   'dʒan',
#   'dʒanaza',
#   'dʒanɢon',
#   'dʒasːusːi',
#   'dʒasːusːi',
#   'dʒasːusːi',
#   'dʒasːusːi',
#   'dʒenali',
#   'dʒenali',
#   'dʒenali',
#   "dʒuhut'i",
#   'dʒuzi',
#   'dʒumadulalʲawwalʲ',
#   'dʒumadulassani',
#   'ʒanub',
#   "ʒulik'i",
#   'zabastowka',
#   'zabor',
#   'zahir',
#   'zahirdːu',
#   'zahru',
#   'zahru',
#   'zahruman',
#   'zajpi',
#   'zaʔipildːu',
#   'zakuska',
#   'zalim',
#   'zalim',
#   'zalim',
#   'zamana',
#   'zamana',
#   'zamana',
#   'zamzal',
#   'zamzal',
#   'zamzal',
#   'zaral',
#   'zaral',
#   'zaral',
#   'zaralaʃa',
#   'zaralloɡusːi',
#   'zaralɬidu',
#   'zaraltʃi',
#   'zarpi',
#   'zasedani',
#   'zijarati',
#   'zijaratiɬir',
#   'zina',
#   'zinahati',
#   'zinaltɬinkudʒijib',
#   'zinaltʃan',
#   'zowti',
#   'zuhmati',
#   'zuhmati',
#   'zulhidʒa',
#   'zulmu',
#   'zulmu',
#   'zulmutʃi',
#   'zulmutʃi',
#   'zunura',
#   'zunuratʃi',
#   'zunuratʃi',
#   'zurrijati',
#   'iɡit',
#   'iɡit',
#   'idara',
#   'idara',
#   'idʒara',
#   "iq'bal",
#   "iq'bal",
#   'ilahi',
#   'ilahi',
#   'ilbis',
#   'ilbis',
#   'ilbis',
#   'illa',
#   'imam',
#   'imam',
#   'iman',
#   'iman',
#   'indʒil',
#   "inq'ilab",
#   'insan',
#   'iprit',
#   "isɢat'i",
#   'islam',
#   'islam',
#   'isparawka',
#   'istakan',
#   'iχtijar',
#   'iʃara',
#   'iʃara',
#   'iʃara',
#   'iʃkal',
#   'iʃkaldːu',
#   "iʃq'u",
#   "iʃq'u",
#   'iʃtampil',
#   'kaʁar',
#   'kaʁar',
#   'kaʁardaʃa',
#   'kaʁardul',
#   'kazijati',
#   'kalam',
#   'kalam',
#   'kalam',
#   'kaluʃi',
#   'kaluʃi',
#   'kalχozi',
#   'kami',
#   'kamil',
#   'kamil',
#   'kamunizi',
#   'kapurdːu',
#   'kapustan',
#   'karawat',
#   'kartuʃi',
#   'kartuʃi',
#   'katʃali',
#   'katʃali',
#   'katʃali',
#   'kaʃiʃi',
#   'kaʃiʃi',
#   'kʷitantsiʔi',
#   'kenpeti',
#   'kep',
#   'kepekːi',
#   'kilisi',
#   'kilametra',
#   'kiri',
#   'kiri',
#   'kiri',
#   'kirpitʃi',
#   'kisaj',
#   'kisakati',
#   'kisakati',
#   'kiʃmiʃi',
#   'koʃːi',
#   'kumeki',
#   'kumeki',
#   'kupesi',
#   "q'abihi",
#   "q'abihi",
#   "q'abihi",
#   "q'abihildːu",
#   "q'am",
#   "q'am",
#   "q'am",
#   "q'am",
#   "q'aniati",
#   "q'aniati",
#   "q'aniatildːu",
#   "q'arzi",
#   "q'arzi",
#   "q'asd",
#   "q'asd",
#   "q'iral",
#   "q'ismati",
#   "q'ismati",
#   "q'ismati",
#   "q'ismati",
#   "q'isːa",
#   "q'isːa",
#   "q'isːa",
#   "q'isːa",
#   "q'isːa",
#   "q'ulhu",
#   "q'ulhu",
#   "q'ulhu",
#   'ɢabul',
#   'ɢadar',
#   'ɢadar',
#   'ɢadi',
#   'ɢadru',
#   'ɢadru',
#   'ɢajda',
#   'ɢajda',
#   'ɢajda',
#   'ɢajda',
#   'ɢajda',
#   'ɢalam',
#   'ɢibla',
#   'ɢibla',
#   'ɢimmati',
#   'ɢimmati',
#   'ɢimmati',
#   'ɢuwwari',
#   'ɢudrati',
#   'ɢudrati',
#   'ɢudrati',
#   'ɢurʔan',
#   "k'enazi",
#   'lazati',
#   'lazati',
#   'lazati',
#   'lazati',
#   'lamusi',
#   'lamusi',
#   'lamusi',
#   'lamusildːu',
#   'lastiʒ',
#   'latur',
#   'litra',
#   'maʁrib',
#   'mahdi',
#   'mahrum',
#   'mahrumdːu',
#   'madrasa',
#   'madʒlis',
#   'mazhab',
#   'mazhab',
#   'maʔiʃati',
#   'maʔiʃati',
#   'maʔiʃati',
#   'majdan',
#   'majdan',
#   'majdan',
#   'majka',
#   'makru',
#   'makru',
#   'makru',
#   'makru',
#   'makrudaʃa',
#   'makrudaʃa',
#   'makrudaʃa',
#   'makrudaʃa',
#   'makruloɡusːi',
#   'makruloɡusːi',
#   'makrutʃi',
#   'makrutʃi',
#   'maktab',
#   'maktab',
#   "maq'ala",
#   "maɢlat'isi",
#   'malajki',
#   'maliki',
#   'malekulmowti',
#   'maɬum',
#   'maɬum',
#   'maɬum',
#   'manzil',
#   'marhaba',
#   'marʒan',
#   "mark'a",
#   "mark'a",
#   'marmalati',
#   'masala',
#   'masɢara',
#   'masɢardaʃa',
#   'masʔala',
#   'masʔala',
#   'masʔala',
#   "maχluq'ati",
#   'maχmar',
#   'maχradʒa',
#   'maʃar',
#   'maʃar',
#   'maʃaʔalla',
#   'maʃaʔalla',
#   'maʃaʔalla',
#   'maʃʁul',
#   'maʃʁulɬir',
#   'maʃhur',
#   'maʃhur',
#   'maʃhur',
#   'maʃhurɬir',
#   'maʃina',
#   'maʃɢil',
#   'maʃɢil',
#   "maʃriq'",
#   'maʃtiɡi',
#   'maʔdan',
#   'maʔdan',
#   'maʔdan',
#   'maʔdan',
#   'maʔiʃati',
#   'maʔna',
#   'maʔna',
#   'maʔrip',
#   'midil',
#   'mizan',
#   'mizan',
#   'mizan',
#   'mizan',
#   'miɢi',
#   'miɢi',
#   'miljan',
#   'miljard',
#   'millati',
#   'millati',
#   'millimetra',
#   'minuti',
#   'misal',
#   'misal',
#   'miskin',
#   'miskin',
#   'miskindːu',
#   "misq'al",
#   "misq'al",
#   'miʔmati',
#   'miʔmati',
#   'mowludi',
#   'monpasːi',
#   'mabarak',
#   'muhadʒir',
#   'muharram',
#   'muhkan',
#   'muhkan',
#   'muhkandːu',
#   'muhru',
#   'muhru',
#   'muhtan',
#   'muʒalat',
#   "muʒik'i",
#   "muq'san",
#   "muq'san",
#   "munapiq'i",
#   "munapiq'i",
#   'muradi',
#   'muradi',
#   'muradi',
#   "mustahiq'i",
#   "mut'itʃi",
#   "mut'itʃi",
#   "mut'iʔildːu",
#   'muχbir',
#   'nabti',
#   'nabti',
#   'nadʒasi',
#   'nadʒasi',
#   'nadʒasi',
#   'nadʒasi',
#   'nazmu',
#   'nazmu',
#   'nazmu',
#   'nazru',
#   'nazru',
#   'nazrujdu',
#   'nazrujdu',
#   "naq'lu",
#   'naɢiʃ',
#   'naɢiʃ',
#   'nanaɢa',
#   'nanaɢa',
#   'nasib',
#   'nasib',
#   'nasib',
#   'nasib',
#   'nasihati',
#   'nasihati',
#   'naslu',
#   'naslu',
#   'naslu',
#   'naslu',
#   'naslu',
#   'naslu',
#   'naʔana',
#   'nijati',
#   'nur',
#   'nur',
#   'nurɢon',
#   'nurloɡusːi',
#   'objawleni',
#   'odaman',
#   'oziruɡu',
#   'ordel',
#   'order',
#   'otpuska',
#   'oχiqan',
#   'pahmu',
#   'pahmu',
#   'pajda',
#   'pajdaloɡusːi',
#   "pajt'un",
#   "pajt'un",
#   'paɢir',
#   'pal',
#   'pal',
#   'pal',
#   'palarsːi',
#   'palatentsa',
#   'palaʃi',
#   "palt'ammu",
#   'paluhan',
#   'paluhan',
#   'paluhan',
#   'paltʃi',
#   'paltʃi',
#   'pamilija',
#   'pana',
#   'pana',
#   'pana',
#   'pana',
#   'panazaraldːu',
#   'pandur',
#   'pandurtʃi',
#   'papruza',
#   'paraʒi',
#   'paraʒi',
#   'paraɢati',
#   'paraɢati',
#   'paraɢati',
#   'pardaw',
#   'pardaw',
#   'pardaw',
#   'pardaw',
#   'pardaw',
#   'pardaw',
#   'pardaw',
#   'pardaw',
#   'pariza',
#   'pariza',
#   'pasati',
#   'pasati',
#   'pasati',
#   'pasaɡildːu',
#   'pasːihi',
#   'patiha',
#   'paturman',
#   'patʃːahi',
#   'pesi',
#   'peʃi',
#   'peʃeti',
#   'pikru',
#   'pikru',
#   'pikru',
#   'pikru',
#   'pikru',
#   'pikru',
#   'pil',
#   'pilpil',
#   'pinʒeki',
#   "pirintʃ'i",
#   'pirjanik',
#   'pirʔan',
#   "pist'oleti",
#   "pist'ol",
#   'poweska',
#   'pomidor',
#   'porostin',
#   'poʃi',
#   'poʃitʃi',
#   'pulan',
#   'pulimeti',
#   'punti',
#   'purɡun',
#   'purman',
#   'putowka',
#   'rabialʲawwalʲ',
#   'rabiassani',
#   'rahati',
#   'rahati',
#   'rahati',
#   'rahmati',
#   'rahmu',
#   'radʒab',
#   'razi',
#   'razildːu',
#   'razildːu',
#   'ramazan',
#   'rezolutsi',
#   'rekamindatsi',
#   "rizq'i",
#   "rizq'i",
#   "riʃwataq'u",
#   'riʃwati',
#   'ruzmal',
#   'ruzmal',
#   'rutʃka',
#   'sabab',
#   'sabab',
#   'sabab',
#   'sabab',
#   'sabranija',
#   'satsializm',
#   'sabur',
#   'sabur',
#   'saburdːu',
#   'saburdoqi',
#   'saʁʷati',
#   'saʁʷati',
#   'saʁʷati',
#   'sadaɢa',
#   'sadaɢa',
#   'sadaɢa',
#   'salazol',
#   'salazol',
#   'saniʔati',
#   'saniʔati',
#   'saniʔati',
#   'saniʔati',
#   'santimetra',
#   'sarʒmu',
#   'saχawati',
#   'saχawatildːu',
#   'saχawatildːu',
#   'setka',
#   'siɡerka',
#   'siɡerka',
#   'sikunti',
#   'simiʃka',
#   'sːabru',
#   'sːabru',
#   'sːabruloɡusːi',
#   'sːabruloɡusːi',
#   'salam',
#   'sːalamati',
#   'sːalamati',
#   'sːalamati',
#   'sːalamatildːu',
#   'sːalamatildːu',
#   'sːalati',
#   'sːandiɡi',
#   'sːapar',
#   'sːapar',
#   'sːapin',
#   "sːapintʃ'uba",
#   'sːaʔati',
#   'sːaʔati',
#   'sːemeti',
#   'sːibira',
#   'sːibiru',
#   'sːihir',
#   'sːihir',
#   'sːihir',
#   'sːihir',
#   'sːihir',
#   'sːihir',
#   'sːihru',
#   'sːihru',
#   'sːijahi',
#   'sːijahi',
#   'sːijahi',
#   'sːipati',
#   'sːipati',
#   'sːipati',
#   'sːipati',
#   'sːipati',
#   'sːipati',
#   'sːipati',
#   "sːirat'i",
#   "sːirat'i",
#   "sːirat'i",
#   "sːirat'i",
#   'sːobonnib',
#   'sːumaʁur',
#   'sːunkatijdu',
#   'sːurati',
#   'sːurati',
#   'sːurati',
#   'sːurati',
#   'sːurati',
#   'sːurati',
#   'sːurati',
#   'sːurati',
#   'subhanalla',
#   'suʔal',
#   'tadbir',
#   'tadbir',
#   'tadbir',
#   'tadbir',
#   'tadbir',
#   'taza',
#   'taza',
#   'taza',
#   'tajpa',
#   'tajpa',
#   'takrar',
#   'takrardːu',
#   "taq'sir",
#   "taq'sir",
#   "taq'sir",
#   "taq'sir",
#   "taq'sir",
#   "taq'sir",
#   'talmatʃi',
#   'talmatʃi',
#   'talon',
#   'tamako',
#   'tamaʃa',
#   'tamaʃa',
#   'tamaʃa',
#   'tamaʃa',
#   'tamaʃaldːu',
#   'tapantʃa',
#   'tapantʃa',
#   'tara',
#   'tara',
#   'tara',
#   'tara',
#   'tara',
#   'tarahi',
#   'tarakan',
#   'tarbija',
#   'tariχːi',
#   'tariχːi',
#   'tariχːi',
#   'tariχːi',
#   'tartib',
#   'tasamahi',
#   'tasamahi',
#   'tasamahildːu',
#   'tasamahildːu',
#   "tasdiq'ijdu",
#   "tasdiq'ijir",
#   'taχ',
#   'taχ',
#   'taχ',
#   'taχʃahar',
#   'tel',
#   'tel',
#   'tilipun',
#   'tetradi',
#   'towba',
#   'towba',
#   'towba',
#   'towrati',
#   'tukan',
#   'tukantʃi',
#   'tumen',
#   'tumen',
#   'tupanɡi',
#   'tupanɡi',
#   'tupanɡi',
#   'turki',
#   'tuχum',
#   'tuχum',
#   'tuʃman',
#   'tuʃman',
#   'tuʃmanɬir',
#   'tuʃmanɬir',
#   'tuʃmanɬir',
#   "t'abiʔati",
#   "t'abiʔati",
#   "t'awusi",
#   "t'awusi",
#   "t'alab",
#   "t'alab",
#   "t'alab",
#   "t'alɢin",
#   "t'ariɢati",
#   "t'aʔam",
#   "t'aʔam",
#   "t'aʔam",
#   "t'uz",
#   "t'upan",
#   "t'upan",
#   'umiwalʲniki',
#   'ummati',
#   'umuru',
#   'umuru',
#   "ust'ar",
#   "ust'ardːu",
#   "ust'arɬir",
#   "ust'arχana",
#   "ust'ol",
#   'uʃkol',
#   'χabar',
#   'χabar',
#   'χabar',
#   'χabar',
#   'χabar',
#   "χabatʃ'abar",
#   "χabatʃ'abar",
#   "χabatʃ'abar",
#   "χabatʃ'abar",
#   "χabatʃ'abar",
#   "χabatʃ'abar",
#   "χabatʃ'abar",
#   'χalati',
#   'χalɢi',
#   'χalɢi',
#   'χalɢi',
#   'χamizi',
#   'χan',
#   'χanɬir',
#   ...],
#  'bagv1239': ["abad'ijab",
#   "abadinabad'aɬːir",
#   "abadinabad'iɬːi",
#   "abar'ona",
#   "abar'ot",
#   "ab'itsarapits'er",
#   "ab'itsarlhar",
#   "apits'ant",
#   "abtabiaɡr'aːpija",
#   "awt'oːbuz",
#   "abt'obus",
#   "abtam'at",
#   "abtan'omija",
#   "abtan'omijab",
#   "abt'eka",
#   "abt'ikar",
#   "abʃiʒ'it",
#   "abʃːeʒ'itija",
#   "aw'alaχir",
#   "aw'alaχir",
#   "aw'araw'armis'ː",
#   "aw'araɡ",
#   "aw'arija",
#   "aw'ans",
#   "awãt'ura",
#   "awãtur'ist",
#   "awãtur'iska",
#   "aɡit'atur",
#   "akit'atsija",
#   'aɡitpũkut',
#   "aɡran'om",
#   "ad'ab",
#   "ad'abotʃ'ub",
#   "adab'ijat",
#   "ad'abqatir",
#   "ad'abtʃ'anasː",
#   "ad'abidab",
#   "ad'amwatʃ'ub",
#   "ad'amhelaba",
#   "adʷ'akat",
#   "adij'al",
#   "adikal'on",
#   "adːel'enija",
#   "adː'il",
#   "azal'ijab",
#   "azal'ijab",
#   "az'arda",
#   "az'artʃ'ek'ub",
#   "azb'ar",
#   "azd'aho",
#   "azd'aho",
#   "azerbiʒ'anaw",
#   "azerbiʒ'anadi",
#   "azerbiʒ'anaj",
#   "az'iazarda",
#   "aj'at",
#   "ajradr'om",
#   "akij'an",
#   "akt'abirbos'ː",
#   "akuʃ'erka",
#   "al'at",
#   "al'aq",
#   "al'aq",
#   "al'aq",
#   "alb'omalb'um",
#   "al'ip",
#   "al'ipa",
#   "alm'as",
#   "alː'ah",
#   "am'an",
#   "am'anat",
#   "am'anmadad",
#   "amerik'anadi",
#   "am'ir",
#   "apar'aɡ",
#   "apir'atsija",
#   "apr'elbos'ː",
#   "arb'aʕzeb",
#   "art'il",
#   "art'is",
#   "arχ'iw",
#   'as',
#   "as'ar",
#   "as'as",
#   "asat'inaw",
#   "asat'inari",
#   "asat'inaj",
#   "asʷ'alt",
#   "as'ir",
#   "ask'ar",
#   "asl'ijab",
#   "ast'awpirulaːh",
#   "ast'aʁpirulaːh",
#   "asːal'amuʕalajkum",
#   "atist'at",
#   "atkr'itka",
#   "atl'as",
#   "atl'itʃnik",
#   'atlitʃnitsa',
#   "aχ'ir",
#   "aχ'irarbaʕ",
#   "aχ'irat",
#   "aχ'irzamana",
#   "aχir'ijab",
#   "aχ'ilaː",
#   "aχr'an",
#   "atʃk'o",
#   "atʃ'ot",
#   "ãb'ar",
#   "amb'ar",
#   "ãbulat'orija",
#   "ãɡ'ultajpa",
#   'ãs',
#   "ãsː'abil",
#   "ãt'ena",
#   "bah'a",
#   "bah'adur",
#   "bah'adur",
#   "badirʒ'an",
#   "b'aza",
#   "baz'ar",
#   "baz'ar",
#   "baz'arɡan",
#   "baj'anab",
#   "baj'anab",
#   "baj'anlhar",
#   "bajd'an",
#   "bajd'an",
#   "bajd'an",
#   "bajr'aq",
#   "bajr'aqulaw",
#   "bajtum'al",
#   "balal'ajka",
#   "bal'ank",
#   "balɡ'araduw",
#   "balɡ'ar'aduj",
#   "balɡ'arari",
#   "baln'itsbaln'itsa",
#   "barak'oːka",
#   "b'arka",
#   "bark'alaː",
#   "bark'alaː",
#   "bark'aman",
#   "bark'at",
#   "bark'at",
#   "bark'at",
#   "b'arkidar",
#   "b'arkidila",
#   "batar'eja",
#   "baʃk'iradi",
#   "baʃm'aq'",
#   "b'aka",
#   "b'anka",
#   "m'aka",
#   "belar'usadi",
#   "bel'et",
#   "bet'eʕinaw",
#   "bet'eʕin",
#   "biblat'eːka",
#   "biblat'eːkar",
#   "b'idʕa",
#   "b'idira",
#   "birɡ'ada",
#   "birɡad'ir",
#   "birz'in",
#   "birz'int",
#   "b'irk'a",
#   "birl'at",
#   "bir'o",
#   "bisk'inab",
#   "bisk'inab",
#   "bisk'inlhar",
#   "bisk'inlhar",
#   "bisk'inlhila",
#   "bism'ilaː",
#   "bit'on",
#   'boz',
#   "b'otʃka",
#   'boʃː',
#   "b'oba",
#   "b'omba",
#   "buht'an",
#   "bukʷ'ar",
#   "bult'in",
#   "bur'aw",
#   "bur'aq'",
#   "burtsil'oz",
#   "busː'umanhak'uj",
#   "busː'umanhek'ʷa",
#   "busː'umanzabi",
#   "busː'umãlhar",
#   "busː'umãlhila",
#   "p'utka",
#   "buχɡ'altir",
#   "buʃ'anka",
#   'wa',
#   "wab'aʕ",
#   "wab'ilaːh",
#   "waɡ'un",
#   "waɡ'un",
#   "wahab'ijadi",
#   "waʕal'eːkumsːalam",
#   "waʕz'a",
#   "waʕz'a",
#   "wazil'in",
#   "waz'ir",
#   "wakz'al",
#   "wak'il",
#   "wak'il",
#   "w'aq'pu",
#   "wal'i",
#   "wal'i",
#   "w'alaː",
#   "w'anːa",
#   "war'aʕab",
#   "war'aʕlhar",
#   "war'is",
#   "wasw'as",
#   "wasw'as",
#   "wasw'as",
#   "was'iɡat",
#   "wat''an",
#   "welesip'et",
#   "wilasip'ed",
#   "wizn'os",
#   'wirdwid',
#   "w'itru",
#   "w'iʃːiw'iʃːiabrazaw'aːni",
#   "ɡaw'ur",
#   "ɡ'aʒimasq'araɬɡ'aʒibuɬu",
#   'ɡaz',
#   "ɡalip'oː",
#   "ɡikt'ar",
#   "ɡinir'al",
#   "ɡubirn'atar",
#   "ɡubern'atar",
#   "ɡurʒ'i",
#   "ɡurʒ'ijaw",
#   "ɡurʒ'ijadiɡurʒ'ijaːri",
#   "ɡurʒ'ijaj",
#   "ʁaz'awat",
#   "ʁaz'i",
#   "ʁaz'i",
#   "ʁal'at'",
#   "ʁap'ulab",
#   "ʁap'ulhar",
#   "ʁap'ulhar",
#   "ʁap'ulhila",
#   "ʁap'ulhila",
#   "ʁar'a",
#   "ʁar'awaʃ",
#   "ʁir'a",
#   "h'awa",
#   "h'awa",
#   "h'awa",
#   'hal',
#   "h'almaʁ",
#   "h'almaʁlhar",
#   "h'idʒra",
#   "hoːbak'ʷab'aː",
#   "hudh'ud",
#   "huʒ'um",
#   "hun'arhun'ari",
#   "hun'arhun'ari",
#   "hun'arhun'ari",
#   "ʕabas'i",
#   "ʕawr'at",
#   "ʕad'at",
#   "ʕad'at",
#   "ʕadat'ijab",
#   "ʕadat'ijab",
#   "ʕadat'ijab",
#   "ʕadat'ijab",
#   "ʕad'atab",
#   "ʕad'atab",
#   "ʕad'atab",
#   "ʕad'atab",
#   "ʕad'il",
#   "ʕad'ilhek'ʷa",
#   "ʕ'adlo",
#   "ʕ'adlowatʃ'ub",
#   "ʕ'adloidab",
#   "ʕ'adlomizan",
#   "ʕadʒ'eːbisː",
#   "ʕadʒ'eːbisː",
#   "ʕadʒ'eːblhar",
#   "ʕadʒ'eːblhar",
#   "ʕadʒ'eːblhar",
#   "ʕadʒ'eːblhar",
#   "ʕadʒ'eːblhila",
#   "ʕaʒ'alʕadʒ'al",
#   "ʕaʒal'aɬʃːetʃ'",
#   "ʕaʒ'uʒat",
#   "ʕaʒ'uʒmaʒuʒ",
#   "ʕaz'ab",
#   "ʕaz'ab",
#   "ʕaz'ab",
#   "ʕaz'abʕaq'uba",
#   "ʕaz'izab",
#   'ʕajb',
#   'ʕajb',
#   'ʕajb',
#   "ʕ'ajbwatʃ'uba",
#   "ʕ'ajbdʒeːr",
#   "ʕ'ajbdʒiːla",
#   "ʕajb'ijab",
#   "ʕ'ajblhajla",
#   "ʕ'ajblhar",
#   "ʕ'ajblhila",
#   "ʕ'ajbtʃ'ʷajdar",
#   "ʕ'ajbtʃ'ʷajdar",
#   "ʕajbtʃ'ʷ'ajdila",
#   "ʕajbtʃ'ʷ'ajdila",
#   "ʕ'aksːeːl",
#   "ʕaq''il",
#   "ʕaq''ilab",
#   "ʕ'aq'lo",
#   "ʕ'aq'lo",
#   "ʕ'aq'lujab",
#   "ʕ'aq'lutʃ'anasː",
#   "ʕaq''uba",
#   "ʕaq''uba",
#   "ʕaq''ubaq'ʷaralhar",
#   "ʕal'am",
#   "ʕal'am",
#   "ʕal'amalhajla",
#   "ʕal'amalhar",
#   "ʕal'amalhila",
#   "ʕal'amat",
#   "ʕal'amat",
#   "ʕal'amat",
#   "ʕal'amatab",
#   "ʕal'amatab",
#   "ʕaldʒ'an",
#   "ʕal'imh'ek'ʷa",
#   "ʕal'imzabi",
#   "ʕam'al",
#   "ʕam'al",
#   "ʕam'al",
#   "ʕam'albertsen",
#   "ʕam'alhoːba",
#   "ʕam'aldʒiːla",
#   "ʕ'amːab",
#   "ʕar'ab",
#   "ʕarab'ijaw",
#   "ʕarab'ijadi",
#   "ʕarab'ijaj",
#   "ʕar'ada",
#   "ʕar'aq'",
#   "ʕar'atsbajd'an",
#   'ʕarz',
#   "ʕarz'a",
#   "ʕasː'ilhar",
#   "ʕat'r'as",
#   "ʕaq'uʃaw",
#   "ʕaquʃ'aj",
#   "ʕaq'uʃadi",
#   "ʕaʃ'iq'",
#   "ʕaʃ'urazeb",
#   "ʕ'elmo",
#   "ʕ'eʃq'oʕ'iʃq'o",
#   "ʕib'adat",
#   "ʕilː'a",
#   "ʕ'iɬizeb",
#   "ʕipr'itʕipr'it'",
#   "ʕipr'itʕipr'it'",
#   "ʕir'aq'adi",
#   "ʕir'aq'aduw",
#   "ʕir'aq'aduj",
#   "ʕ'ormi",
#   "ʕ'uzro",
#   "ʕ'uzro",
#   "ʕ'uzro",
#   "ʕ'uzrujab",
#   "ʕ'umra",
#   "ʕur'us",
#   "ʕurus'idːi",
#   "ʕur'us'aχ",
#   "ʕur'usʕurusmis'ː",
#   "ʕurusul'uw",
#   "ʕurusul'uj",
#   "ʕũɡ'urbats'a",
#   "d'awla",
#   "daʕb'a",
#   "daʕb'a",
#   "daʒ'aldaːrʒ'al",
#   "daʒ'aldaːrʒ'al",
#   "da'imab",
#   "da'imda",
#   "da'imlhar",
#   "da'imlhila",
#   "dakl'ad",
#   "dak'umẽt",
#   "dal'il",
#   "d'aːma",
#   "damin'o",
#   "daraʒ'a",
#   "daraʒ'a",
#   "daraʒ'a",
#   "dar'ambazar",
#   "darm'an",
#   "dar'u",
#   "dar'uɬ",
#   "d'aska",
#   'dats',
#   "dek'abirbos'ː",
#   "deleɡ'at",
#   "deput'at",
#   "der'ektur",
#   "dib'ir",
#   "dib'ir",
#   "diw'an",
#   "diw'an",
#   "diw'an",
#   "diw'an",
#   "diʒ'urnalhar",
#   "diʒ'urna",
#   "dikt'ant",
#   'din',
#   "din'ijab",
#   "diriz'in",
#   "duʕ'a",
#   "duʕ'a",
#   "dun'eːl",
#   "dun'eːl",
#   "dun'eːlbalaɬːa",
#   "dun'elbaːb",
#   "dun'eːlʕalam",
#   "dur'usab",
#   "dur'usab",
#   "dur'usab",
#   "dʒaw'ab",
#   "dʒaw'ab",
#   "dʒawab'ijab",
#   "dʒawh'ar",
#   "dʒah'ilab",
#   "dʒah'ilhar",
#   "dʒah'ildʒah'ilahlo",
#   "dʒaz'a",
#   "dʒ'azma",
#   "dʒal'at'",
#   "dʒam'aʕat",
#   'dʒan',
#   'dʒan',
#   "dʒ'anabi",
#   "dʒan'awar",
#   "dʒan'aza",
#   "dʒ'antʃ'anasː",
#   "dʒasː'usːdʒãsː'usː",
#   "dʒasː'usːlhar",
#   "dʒih'ad",
#   'dʒĩdʷ',
#   'dʒild',
#   'dʒuz',
#   "dʒum'adulawal",
#   "dʒum'adulaχir",
#   "ʒuh'ut'adi",
#   "ʒuml'a",
#   "ʒul'an",
#   "ʒurn'al",
#   "zabaːn'ijat",
#   "zaban'ijatadi",
#   "zaw'al",
#   "zaw'ot",
#   "zawχ'uz",
#   "zah'irab",
#   "zah'irlhajla",
#   "zah'irlhalar",
#   "zah'irlhar",
#   "zah'irlhila",
#   "z'ahru",
#   "z'ahruzaq'um",
#   "z'ahruɬ",
#   "z'ahrujab",
#   "zahrum'an",
#   "zaʕib'ab",
#   "zaʕ'iblhajla",
#   "zaʕ'iblhalar",
#   "zaʕ'iblhar",
#   "zaʕ'iblhar",
#   "zaʕ'ibhila",
#   "zaʕ'ibhila",
#   "zaʕpir'an",
#   "z'ajma",
#   "zajt'un",
#   "zak'aːt",
#   "zak'on",
#   "zakon'ijab",
#   "z'aksa",
#   "zak'uska",
#   "zaq''um",
#   "zaq''um",
#   "zal'im",
#   "zam'anazam'an",
#   "zamz'am",
#   "zamz'am",
#   "zamist'aːtil",
#   "zar'ar",
#   "zaral'ijab",
#   "zaral'ijab",
#   "zasid'atil",
#   "zij'arat",
#   "z'ikir",
#   "z'ina",
#   "z'ulq'aʕida",
#   "zulm'at",
#   "z'ulmu",
#   "z'ulmujab",
#   "z'ulmuɬ",
#   "z'ulmuɬːir",
#   "zumr'ud",
#   "zumr'ud",
#   "zur'ijat",
#   "z'urma",
#   "zurm'iqan",
#   "iʕtiq''ad",
#   "id'ara",
#   "idʒ'ara",
#   "izraʕ'il",
#   "izraʕ'il",
#   "ij'ulbos'ː",
#   "ij'unbos'ː",
#   "ikr'am",
#   "iq'b'al",
#   "iq'b'alwatʃ'ub",
#   "iq'b'alwatʃ'lhar",
#   "iq'b'alidab",
#   "iq'b'alidalhar",
#   "ilb'is",
#   "ilb'is",
#   "im'am",
#   "im'am",
#   "im'an",
#   "im'an",
#   "inwal'id",
#   "inq'il'ab",
#   "ins'an",
#   "insan'ijab",
#   "insan'ijat",
#   "ins'ap",
#   "ins'ap",
#   "ins'apab",
#   'irsː',
#   "iskal'ad",
#   "isl'am",
#   "isl'am",
#   "ist'akan",
#   "istal'oːwa",
#   "istiq''at",
#   "ist'ol",
#   "ist'orija",
#   "ist'oroʒ",
#   "istr'aχ",
#   "istr'aχ",
#   "iχtij'ar",
#   "iχtil'at",
#   "iʃ'ariʃ'ara",
#   "iʃk'al",
#   "iʃk'al",
#   "iʃk'ap",
#   "iʃk'oːl",
#   "ĩɡil'isĩɡil'ismis'ː",
#   "ĩɡil'isadi",
#   "ĩɡil'isaduw",
#   "ĩɡil'isaduj",
#   "ĩɡir'iz",
#   "ĩdʒ'il",
#   "ĩkub'atar",
#   "ĩɬːaz'arda",
#   "ĩstit'ut",
#   "ĩter'esab",
#   'ja',
#   'ja',
#   "jab'u",
#   "jahud'ijaw",
#   "jahud'ijadi",
#   "jahud'ijaj",
#   "jaʒ'uʒmaʒuʒ",
#   "jaq''inab",
#   "jaq''inab",
#   "jaq''inda",
#   "jaq''ut",
#   "jar'aʁ",
#   "jarm'uka",
#   "jas'in",
#   "jat'im",
#   "j'aʃik'",
#   "kabard'inaw",
#   "kabard'inadi",
#   "kabard'inaj",
#   "kabard'inkabard'inmis'ː",
#   "kab'ina",
#   "kabin'et",
#   "kaws'ar",
#   "kaʁ'ar",
#   "kaʁ'ar",
#   "kaʁ'ar",
#   "k'ahru",
#   "k'aʕba",
#   "kaz'aχadi",
#   "kaz'aχaduw",
#   "kaz'aχaduj",
#   "kaz'aχkaz'aχmis'ː",
#   "kaz'ijat",
#   "kaz'eːta",
#   "kaz'iːt",
#   "kaz'iːtʒurnal",
#   "kal'am",
#   "kal'am",
#   "kal'as",
#   "kalid'or",
#   "kal'ima",
#   "kalĩd'ar",
#   "kalm'ikadi",
#   "kalm'ikaduw",
#   "kalm'ikaduj",
#   "kalm'ikkalm'ikmis'ː",
#   "kaloɡurʒ'ikalo",
#   "kam'ada",
#   "kamãdir'oːka",
#   "k'amidajlak'amhidajla",
#   "k'amidalar",
#   "k'amidar",
#   "k'amidar",
#   "k'amidila",
#   "k'amidila",
#   "kam'ilab",
#   "kam'ilab",
#   "kam'ilhajla",
#   "kam'ilhajla",
#   "kam'ilhalar",
#   "kam'ilhalar",
#   "kam'ilhar",
#   "kam'ilhar",
#   "kam'ilhila",
#   "kam'ilhila",
#   "k'amira",
#   "kanik'ul",
#   "kap'aːrat",
#   "kap'e",
#   "kapit'an",
#   "kapr'ub",
#   "kap'ulhar",
#   "kap'ulhila",
#   "kap'ulhila",
#   "kap'urhak'uj",
#   "kap'urhek'ʷa",
#   "kap'urhek'ʷa",
#   "kap'urdabitʃ'ab",
#   "kapurdabitʃ'ab'ela",
#   "kap'usta",
#   "karaw'at",
#   "kard'un",
#   "kard'un",
#   "karaw'an",
#   "karaw'an",
#   "karm'anbaʃ",
#   "k'arta",
#   "k'asːa",
#   "kast'um",
#   "kaʃ'iʃ",
#   "kãb'ajn",
#   "kãdid'at",
#   "kãp'ot",
#   "kãs'er",
#   "kãs'erwa",
#   "kãts'ert",
#   'kep',
#   'kep',
#   'kep',
#   'kep',
#   "k'epχːutʃ'",
#   "kil'isa",
#   "kil'onka",
#   "kil'oka",
#   "kir'i",
#   "kirp'itʃ",
#   "kirp'itʃ",
#   "kis'eː",
#   "kit'ajadi",
#   "kit'ajaduw",
#   "kit'ajaduj",
#   "kiʃm'iʃ",
#   "k'opta",
#   "k'opi",
#   "k'opija",
#   "k'ortadi",
#   "k'ortaduw",
#   "k'ortaduj",
#   "kul'ak",
#   "kult'ura",
#   "k'ueuʕalam",
#   "kum'uk",
#   "kup'e",
#   "kup'ets",
#   "kupl'et",
#   "kurʒ'ok",
#   "kurp'a",
#   'kurs',
#   "k'ukni",
#   "kũt'aʁ",
#   "q'ab'ulab",
#   "q'ab'ulhila",
#   "q'ab'uldʒeːr",
#   "q'ab'uldʒeːr",
#   "q'ab'uldʒiːla",
#   "q'ab'uldʒiːla",
#   "q'awmq'am",
#   "q'ah'aldʒeːrq'ah'ardʒeːr",
#   "q'ah'ardʒiːlaq'ah'aldʒila",
#   "q'ah'arlhila",
#   "q'aʕid'aq'ajd'aɬː",
#   "q'aʕid'aq'ajd'aɬː",
#   "q'aʕid'eːbaɬ",
#   "q'ad'ar",
#   "q'ad'ar",
#   "q'ad'i",
#   "q''adru",
#   "q''adroidob",
#   "q''adroidob",
#   "q'aʒ'arq'aʒ'armis'ː",
#   "q'aʒ'araw",
#   "q'aʒ'aradi",
#   "q'aʒ'araj",
#   "q'aj'im",
#   "q'aj'imlhar",
#   "q'al'am",
#   "q'an'aʕalhajla",
#   "q'an'aʕalhar",
#   "q'an'aʕalhila",
#   "q'an'aʕat",
#   "q'an'aʕatab",
#   "q'arz",
#   "q''arzila",
#   "q'asd",
#   "q'asd",
#   "q'at'r'a",
#   "q''ijamasːezeb",
#   "q''ibla",
#   "q''ibla",
#   "q''imat",
#   "q''imat",
#   "q''imat",
#   "q''imat",
#   "q''imat'ʷatʃ'ub",
#   "q'imatidab",
#   "q'ir'al",
#   "q'ir'al",
#   "q'ism'at",
#   "q''isːa",
#   "q'isː'asː",
#   "q''uwat",
#   "q''uwatab",
#   "q'udr'at",
#   "q'udr'atab",
#   "q'ulh'u",
#   "q'ulh'u",
#   "q'or'an",
#   "q''urmaruqar",
#   "q'urmaruq'ujoːbzeb",
#   "q''ut'bu",
#   "k''abli",
#   "k'eb'ek'",
#   "laz'at",
#   "laz'atab",
#   "laz'atʷatʃ'ub",
#   "l'ajla",
#   "l'ajlatuq'adrol'ajlatutɬ'adroɬrelha",
#   'lak',
#   "l'amjalid",
#   "lam'us",
#   "lam'us",
#   'namus',
#   'namus',
#   "lam'uslhar",
#   "lam'uslhila",
#   "lap'an",
#   "latar'eja",
#   "lãq'l'anq'",
#   "lezɡ'inadilezɡ'inaːri",
#   "lezɡ'inaduw",
#   "lezɡ'inaduj",
#   "lezɡ'inlezɡ'inmis'ː",
#   "literat'ura",
#   "l'itra",
#   "mawl'id",
#   "mal'ud",
#   "maɡar'itʃ",
#   "maɡnitap'on",
#   "maʁr'ib",
#   "mah'ari",
#   "mah'ari",
#   "maʕd'an",
#   "maʕd'in",
#   "maʕ'iʃat",
#   "maʕn'a",
#   "maʕn'a",
#   "maʕn'a",
#   "maʕn'awatʃ'ub",
#   "maʕn'awatʃ'ub",
#   "maʕna'idab",
#   "maʕna'idab",
#   "maʕna'idab",
#   "maʕn'aɬ",
#   "maʕn'aɬ",
#   "maʕn'aɬ",
#   "maʕnat'ub",
#   "madan'ijat",
#   "madr'asa",
#   "maʒ'it",
#   "maʒl'ismadʒl'is",
#   "m'ajbos'ː",
#   "m'ajka",
#   "m'ajlikulmawt",
#   "m'ajlikulmawt",
#   "mal'ikumut",
#   "mal'ikumut",
#   "n'akro",
#   "makt'ab",
#   "maq''ala",
#   "maq'lat''ismaq'lat'its",
#   'mal',
#   'mal',
#   "malʕ'un",
#   "mal'eːk",
#   "mal'ajk",
#   "mal'ik",
#   "maml'aka",
#   "mant'iq'ʕelmo",
#   "marw'anhĩts'a",
#   "marʒ'an",
#   "m'ark'a",
#   'mart',
#   "m'artbos'ː",
#   "m'arʃ",
#   "m'arʃal",
#   "mas'ala",
#   "mas'ala",
#   "m'asalaː",
#   "masq'ara",
#   "masq'araχːutʃ'",
#   "masq'araχːutʃ'",
#   "masː'aʒ",
#   "matats'ik",
#   "mat'uʃka",
#   "mat'uʃka",
#   "mat'uʃka",
#   "maχl'uq'at",
#   "maχl'uq'at",
#   "maχm'armaχm'ur",
#   "maχr'adʒ",
#   "maʃʁ'ulab",
#   "maʃʁ'ulhar",
#   "maʃʁ'ulhila",
#   "maʃh'urab",
#   "maʃh'urlhar",
#   "maʃh'urlhila",
#   "maʃ'ina",
#   "maʃ'ina",
#   "maʃ'inahorko",
#   "maʃ'inka",
#   "maʃq''il",
#   "maʃq''ilidaw",
#   "maʃq''iltʃ'ana",
#   "maʃr'iq'",
#   "m'aːʃaːlaː",
#   "m'aːʃalaːh",
#   "mãɡ'oladi",
#   "mãɡ'oladuw",
#   "mãɡ'oladuj",
#   "mãɡ'olmãɡ'olmis'ː",
#   "mãz'il",
#   "m'etram'itri",
#   "niʕm'at",
#   "niʕm'at",
#   "miʕr'adʒ",
#   "mil'itsa",
#   "mil'itsa",
#   "milː'at",
#   "mie'on",
#   "min'istir",
#   "min'ut",
#   'mirkmilkmulk',
#   'mirkmilkmulk',
#   "m'irkab",
#   "m'ilkab",
#   "mis'al",
#   "mis'al",
#   "mis'alhibo",
#   "misal'ijab",
#   "misr'ijadi",
#   "misr'ijaduw",
#   "misr'ijaduj",
#   "mit'istajpa",
#   "muhm'alhar",
#   "muhm'alhila",
#   "muhm'arabmuhum'adab",
#   "m'uhro",
#   "m'uhro",
#   "muʕal'im",
#   "mud'un",
#   "muq's'anab",
#   "muq's'alhar",
#   "muq's'alhar",
#   "muq's'anlhila",
#   "munap'iq'",
#   "munap'iq'",
#   "mup'aʕat",
#   "mup'aʕatab",
#   "mup'aʕatab",
#   "mup'aʕatʷatʃ'ub",
#   "mup'aʕatʷatʃ'ub",
#   "m'upti",
#   "mur'ad",
#   "mur'ad",
#   "mur'ad",
#   "mur'adʷatʃ'ub",
#   "mur'adʷatʃ'ub",
#   "mur'id",
#   "mur'uwat",
#   "mur'uwatiɬ",
#   "mur'uwatiɬ",
#   "murʃ'id",
#   "mutaʕ'il",
#   "bet'eʕin",
#   "mut'iʕ'ab",
#   "mut'iʕ'ab",
#   "mut''iʕlhajla",
#   "mut''iʕlhajla",
#   "mut''iʕlhalar",
#   "mut''iʕlhalar",
#   "mut''iʕlhar",
#   "mut''iʕlhila",
#   "muχb'ir",
#   "muʃr'ik",
#   "muʔm'inab",
#   "muʔm'inlhar",
#   'muʔmĩlhila',
#   'nabi',
#   'nabi',
#   'nawʕ',
#   "naʕan'a",
#   "naʕan'a",
#   "nadʒ'as",
#   "n'azmo",
#   "na'ib",
#   "naj'aːbirbos'ː",
#   "n'aq'iʃ",
#   "n'aq'lo",
#   "n'aq'lo",
#   "nal'oknal'ok'",
#   "n'apaq'a",
#   'naps',
#   'nart',
#   'nart',
#   "nas'ab",
#   "n'aslo",
#   "n'aslo",
#   "nat'iʒat",
#   "n'eɡraw",
#   "n'eɡraduw",
#   "n'eɡradi",
#   "n'eɡraj",
#   "n'eɡraduj",
#   "n'emtsadi",
#   "n'emtsaduw",
#   "n'emtsaduj",
#   "n'iʒat",
#   "niz'am",
#   "n'ikel",
#   'nul',
#   "noːm'ir",
#   "n'orma",
#   "n'orma",
#   "nuʁ'ajadi",
#   "nuʁ'ajaduw",
#   "nuʁ'ajaduj",
#   "nuʁ'ajnuʁ'ajtʃaj",
#   "n'uʒumʕelmo",
#   "nuk'ar",
#   'nur',
#   "p'abrika",
#   "paw'idla",
#   "p'ahmap'ahmo",
#   "p'ahmap'ahmo",
#   "p'ampo",
#   "p'ampo",
#   "p'ahmawatʃ'ub",
#   "p'ampowatʃ'ub",
#   "p'ahmaɬ",
#   "p'ahmaɬ",
#   "p'ahmaɬ",
#   "paz'ilat",
#   "pajd'a",
#   "pajd'a",
#   "pajd'a",
#   "pajd'awatʃ'ub",
#   "pajd'awatʃ'ub",
#   "pajd'ajab",
#   "paq''ir",
#   ...],
#  'botl1242': ["abad'adila",
#   "abad'ijab",
#   "abaz'inaw",
#   "abaz'inaj",
#   "abaz'inal",
#   "abar'ona",
#   "abjawl'eni",
#   "ab'ort",
#   "abt'abus",
#   "abtam'at",
#   "abtar'utʃka",
#   "abt'eka",
#   "abχ'azaw",
#   "abχ'azaj",
#   "abχ'azal",
#   "aw'al",
#   "aw'alʔaχ'ir",
#   "aw'alʔaχ'ir",
#   "aw'ans",
#   "aw'araɡ",
#   "aw'ari",
#   "awl'aq",
#   "awl'aq",
#   "awl'aq",
#   "awl'aq",
#   "awtabioɡr'api",
#   "awtamab'il",
#   "awtam'at",
#   "awtamaʃ'ina",
#   "awtar'utʃka",
#   "awt'obus",
#   "awtʃ'arka",
#   "aɡar'od",
#   "aɡran'om",
#   "aɡran'omɬi",
#   "aɡ'ulaw",
#   "aɡ'ulaj",
#   "aɡ'ulal",
#   "ah'oʔaha",
#   "ad'ab",
#   "ad'abħurm'at",
#   "ad'abqat'ir",
#   "ad'abqat'ir",
#   "ad'abqat'ir",
#   "ad'abqat'irɬːi",
#   "ad'abqat'irɬːi",
#   "ad'abqul'uq",
#   "ad'abqul'uqɬːi",
#   "ad'abijat",
#   "ad'abɬːi",
#   "ad'abɬːi",
#   "ad'aʁʷa",
#   "ad'aʁʷa",
#   "ad'aʁʷa",
#   "ad'aʁʷa",
#   "ad'aʁʷa",
#   "ad'aʁʷa",
#   "ad'am",
#   "ad'amal",
#   "ad'amal",
#   "adamal'ubtsːub",
#   "adamal'uditsːub",
#   "ad'amɬi",
#   "ad'amtsːub",
#   "adwak'at",
#   "adwak'atɬi",
#   "adː'el",
#   "adːel'eni",
#   "adːel'enija",
#   "adʒ'araw",
#   "adʒ'araj",
#   "adʒ'aral",
#   "adiɡ'ejaw",
#   "adiɡ'ejaj",
#   "adiɡ'ejal",
#   "adiɡ'ejtsaw",
#   "adij'al",
#   "adikal'on",
#   "adin'otʃka",
#   "az'aʔazar",
#   "az'aʔazar",
#   "az'ajrek'un",
#   "az'ajskabaɬi",
#   "azal'ijab",
#   "az'alikun",
#   "azar'uda",
#   "az'arts'ida",
#   "azb'ar",
#   "azd'aha",
#   "azd'aha",
#   "azd'aha",
#   "azerbiʒ'anaw",
#   "azerbiʒ'anaj",
#   "azerbiʒ'anal",
#   "azn'ajbahad'ur",
#   "azn'ajbahad'ur",
#   "aj'at",
#   "ak'atsi",
#   "akb'ar",
#   "aki'an",
#   "ak'op",
#   'aktebrʲonok',
#   'aktjabir',
#   "ak'ula",
#   "akup'ant",
#   "akup'atsi",
#   "atɬ'itʃnik",
#   "alaɡ'irhĩhu",
#   "al'ah",
#   "al'at",
#   "al'at",
#   "al'aʃːuχaχob",
#   "alban'ijaw",
#   "alb'om",
#   "alʒ'an",
#   "alʒ'iraw",
#   "alim'ent",
#   "al'ip",
#   "al'ip",
#   "al'ip",
#   "al'ipa",
#   "alipul'an",
#   "all'ah",
#   "alm'as",
#   "alm'as",
#   "alp'awit",
#   "aman'al",
#   "am'anallah",
#   "am'anallah",
#   "am'anat",
#   "am'anat",
#   "am'anat",
#   "ambulat'ori",
#   "amerik'aɬi",
#   "amerik'anaw",
#   "am'in",
#   'amma',
#   "amn'isi",
#   "ansː'ambil",
#   "ant'ena",
#   "ap'araɡ",
#   "ap'araɡ",
#   "ap'araɡɬi",
#   "apar'at",
#   "apils'in",
#   "apir'atsi",
#   "apir'atsija",
#   "apits'er",
#   "apitsi'anka",
#   "apr'el",
#   "apt'eka",
#   "apt'ekar",
#   "apʃː'iti",
#   "arb'aʕ",
#   "arbaʕz'iw",
#   "ardʒ'an",
#   "ar'enda",
#   "aripm'etika",
#   "ark'estr",
#   "art'el",
#   "art'iska",
#   "art'isɬi",
#   "art'ist",
#   "as'ar",
#   "as'ar",
#   "as'ar",
#   "as'arbeq'in",
#   "asar'aj",
#   "asar'i",
#   "asar'i",
#   "asar'aj",
#   "asar'ajχab",
#   "as'arda",
#   "as'ardala",
#   "asar'i",
#   "as'arir",
#   "asarsː'ea",
#   "asarχʷ'ala",
#   "as'arχʷala",
#   "asat'inaw",
#   "asat'inaj",
#   "asat'inal",
#   "asʷ'alt",
#   "aset'inaw",
#   "aset'inaj",
#   "aset'inal",
#   "as'ir",
#   "as'ir",
#   "ask'ar",
#   "ask'ar",
#   "ask'ar",
#   "asl'ijab",
#   "asl'u",
#   "asːal'amʕalajkum",
#   "ast'awka",
#   "ast'aʁpirullah",
#   "atl'as",
#   "at'aka",
#   "atw'erka",
#   "atist'at",
#   "atkr'itka",
#   "atl'itʃnik",
#   "atr'ez",
#   "aħʷ'alħal",
#   "aħm'aq'",
#   "aħm'aq'ab",
#   "aħm'aq'aw",
#   "aħm'aq'ɬi",
#   "aχ'ir",
#   "aχ'ir",
#   "aχ'ir",
#   "aχ'iralda",
#   "aχ'irat",
#   "aχir'ijab",
#   "aχir'ijab",
#   "aχ'irla",
#   "aχ'irla",
#   "atst'awka",
#   "atst'awkaɬisːu",
#   "atʃk'ibaɬi",
#   "atʃk'o",
#   "atʃː'ot",
#   "atʃː'otutʃː'otɡ'utʃ'ir",
#   "baɡlaʒ'an",
#   "bah'a",
#   "bah'a",
#   "bah'adur",
#   "bah'adur",
#   "bah'adur",
#   "bah'adurɬi",
#   "bah'adurɬi",
#   "bah'adurɬi",
#   "b'aza",
#   "baz'ar",
#   "baz'ar",
#   "baz'ar",
#   "baz'ar",
#   "baz'ar",
#   "baz'arbajd'an",
#   "baz'araɬi",
#   "baz'araɬir'eq'a",
#   "baz'arɡan",
#   "baz'arɡan",
#   "baz'arɡanɬi",
#   "baz'arziw",
#   "baz'arziw",
#   "baz'arħarq'",
#   "baj'anab",
#   "baj'anɬi",
#   "bajd'an",
#   "bajd'an",
#   "bajd'an",
#   "bajr'am",
#   "bajr'aq",
#   "bajr'aqulaw",
#   'bak',
#   "bak'abaχar'aj",
#   "bak'ar'aj",
#   "bak'ar'aj",
#   "bak'ar'ajχab",
#   "bak'al",
#   "baklaʒ'an",
#   "balal'ajka",
#   "bal'ank",
#   "bal'at",
#   "balɡ'araw",
#   "balɡ'araw",
#   "balɡ'araj",
#   "balɡ'araj",
#   "balɡ'aral",
#   "balɡ'aral",
#   "balɡ'aralub",
#   "balɡ'arka",
#   "balz'am",
#   "balk'araw",
#   "balk'araj",
#   "balk'araj",
#   "balk'aral",
#   "balk'aralub",
#   "baln'itsa",
#   "baln'itsa",
#   "bal'on",
#   "baluʁ'i",
#   "bal'uʁir",
#   "balʃiw'ik",
#   "ban'an",
#   "bander'ol",
#   "b'ani",
#   'bank',
#   "b'anka",
#   "b'anka",
#   "b'anka",
#   "bank'et",
#   "ba'ow",
#   "bar'ak",
#   "bar'akat",
#   "bark'aj",
#   "b'arka",
#   "bark'aːtaɬo",
#   "bark'aːtaχob",
#   "bark'aj",
#   "bark'ajr",
#   "barkajχ'ab",
#   "bark'ala",
#   "bark'ala",
#   "bark'alla",
#   "bark'alla",
#   "b'arkaɬi",
#   "b'arkaɬi",
#   "b'arkaɬːi",
#   "bark'at",
#   "bark'at",
#   "b'aχaχaj",
#   "baχil'i",
#   "baχil'ajχo",
#   "baχ'ilir",
#   "baχ'iliχab",
#   "baʃk'iraw",
#   "baʃk'iraj",
#   "baʃk'iral",
#   "baʃk'iralub",
#   "baʃl'uq",
#   "baʃm'ak",
#   'beɡ',
#   "belar'usaw",
#   "belar'usaj",
#   "belar'usal",
#   "belɡ'ijtsaw",
#   "belɡ'ijtsaj",
#   "belɡ'ijtsal",
#   "bel'et",
#   "benzaw'oz",
#   "benz'in",
#   "b'erχin",
#   "bet'on",
#   "bik'a",
#   "bik'a",
#   "bik'a",
#   "bik'a",
#   "bitɬ''ibeʃunazar'uda",
#   "bil'et",
#   "bili'ard",
#   "binz'in",
#   'bint',
#   "birɡ'ada",
#   "birɡad'ir",
#   "birɡad'irɬi",
#   "birz'ent",
#   "bir'itur",
#   "bir'o",
#   'bis',
#   "bism'illa",
#   "bit'on",
#   "bit'un",
#   "bolʃew'ik'alub",
#   "b'omba",
#   "bor'o",
#   "bor'o",
#   'borʃ',
#   "buʁ'a",
#   "buʁ'a",
#   "buʁ'oɬːi",
# ...
#   "tamaʃ'ab",
#   "tamaʃ'ab",
#   "t'amaʃaʕalamat",
#   "t'amaʃaʕalamat",
#   "tam'aʃaɬaɬa",
#   "t'amaʃaːbχʷa",
#   "t'amaʃaːbχʷa",
#   "tamaʃ'aːɬa",
#   "tam'ãtʃa",
#   "tapt'ar",
#   "t'arbija",
#   "tar'iχ",
#   "tast'iq'",
#   "tat'araw",
#   "tat'araj",
#   "tat'ardi",
#   'taχ',
#   "taχt'a",
#   "t'aχʃahar",
#   "t'ilmatʃ",
#   "t'itrat",
#   'tol',
#   "toχt'ur",
#   "t'ukan",
#   "tum'en",
#   "turk'abdi",
#   "turk'aw",
#   "turk'aj",
#   "turk'i",
#   "t'urpa",
#   "tuχ'um",
#   "tuʃm'an",
#   "tuʃm'an",
#   "tuʃm'ãdilob",
#   "t'abiʕ'at",
#   "t'abiʕ'at",
#   "t'abiʕ'atʕamal",
#   "t'aw'us",
#   "t'aʕ'am",
#   "t'aʕ'am",
#   "t'al'ab",
#   "t'al'ab",
#   "t'am'er",
#   "t'ariq''at",
#   "t'up'an",
#   "uzb'ekaw",
#   "uzb'ekaj",
#   "uzb'ekdi",
#   "ukrain'aw",
#   "ukra'inaj",
#   "ukra'ĩdi",
#   'umat',
#   'umat',
#   "urq'ub",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "ust''ul",
#   "uχ'adnoj",
#   "uʃk'ul",
#   "uʃt'er",
#   "uʃterɬ'er",
#   "uʃt'intsa",
#   'χajr',
#   "χ'albat",
#   "χalʕ'at",
#   "χ'alq'e",
#   "χ'alq'eʕalam",
#   'χan',
#   "χanɬ'er",
#   "χ'asjat",
#   "χasː'ab",
#   "χasː'ab",
#   "χ'at'e",
#   "χãdaq'",
#   "χij'al",
#   "χij'al",
#   "χij'al",
#   "χij'anaɬaɬa",
#   "χij'anaɬer",
#   "χij'anaɬer",
#   "χij'anatob",
#   "χːab'ar",
#   "χːab'ar",
#   "χːab'arkalam",
#   "χːabatʃ'ab'ar",
#   "χː'azina",
#   "χː'azina",
#   "χː'azina",
#   "χːãʒ'ar",
#   "χː'urma",
#   "χːur'um",
#   "qab'anqap'an",
#   'qaz',
#   "qaz'am",
#   "qal'a",
#   "qal'a",
#   "qal'a",
#   "qaraw'ul",
#   "qar'awulɬer",
#   "qarm'uz",
#   "qũd'aʁ",
#   "qũd'aʁ",
#   "x'oɬidob",
#   "qaq'iq'atj'a",
#   "ts'ebq'aʕidatɬ",
#   "ts'ebq'aʕidja",
#   "tsiɡ'anaw",
#   "tsiɡ'anaj",
#   'tsiɡãdi',
#   "tʃad'ir",
#   "tʃajd'an",
#   "tʃak'ar",
#   "tʃaq''ala",
#   "tʃap'ar",
#   "tʃarχː'e",
#   "tʃetʃan'aw",
#   'tʃetʃanaj',
#   "tʃetʃ'ãdi",
#   "tʃin'i",
#   "tʃin'i",
#   "tʃir'aq",
#   "tʃiχotk'a",
#   "tʃorp'a",
#   'tʃːit',
#   "tʃ'atʃ''a",
#   "ʃawq'",
#   "ʃawq'",
#   "ʃ'ahadaɬer",
#   "ʃah'ar",
#   'ʃal',
#   "ʃ'arʕe",
#   "ʃiw'ed",
#   "ʃiw'edːi",
#   "ʃiʃ'aw",
#   "ʃur'at",
#   "ʃːak'ab",
#   "ʃːak'ab",
#   "ʃːakɬaɬ'a",
#   "ʃːakɬaɬ'a",
#   "ʃːakɬaɬ'a",
#   "ʃːakɬ'er",
#   "ʃːakɬ'er",
#   "ʃːakɬ'er",
#   "ʃːakɬid'ob",
#   "ʃːakɬid'ob",
#   "ʃːʷ'apir",
#   'ʃːejχː',
#   "ʃː'et'an",
#   "ʃː'ipaner",
#   "ʃː'iper"],
#  'tind1238': ["abad'eːtɬa",
#   "aw'alaχir",
#   "adj'ar",
#   "aʒ'uʒimaʒuʒi",
#   "az'aazarda",
#   "az'iazar",
#   "az'ahu",
#   "az'ahu",
#   "az'arda",
#   "az'artʃ'oː",
#   "al'ati",
#   "al'aχa",
#   "al'aχa",
#   "al'aχa",
#   "alm'asi",
#   "am'anata",
#   'amru',
#   "ap'araɡʲi",
#   "ar'aq'i",
#   "arb'aʕi",
#   "arb'aʕizebu",
#   "as'ara",
#   "as'ar",
#   "ask'ar",
#   "asl'ijab",
#   "asːalamʕal'eːkum",
#   "aχ'ir",
#   "aχ'irla",
#   "aχ'ilːa",
#   'aχiːrɬːilala',
#   "aχ'iqan",
#   "aħʷ'alħal",
#   "aʃaw'uzi",
#   "b'aha",
#   "bah'adur",
#   "baz'arɡan",
#   "baz'arzebu",
#   "baz'arħaq'i",
#   "baj'anab",
#   "baj'anab",
#   "baj'ada",
#   "baj'aɬar",
#   "bajd'an",
#   "bajd'an",
#   "bajd'an",
#   "bajr'aqi",
#   "bajr'aqulaw",
#   "bajt'aman",
#   "balʕ'un",
#   "b'arka",
#   "bark'alːa",
#   "bark'alːabak'alːa",
#   "bark'aman",
#   "bark'ati",
#   "bark'ati",
#   "bark'atibaqijub",
#   "bark'atitɬa",
#   "bark'atitɬa",
#   "bark'atitɬa",
#   "b'arkijar",
#   "b'arkiːɬʲa",
#   "baχ'il",
#   "baχ'il",
#   "baχ'ilɬʲar",
#   "baχ'ilɬʲar",
#   "baχ'ilɬiɬʲa",
#   "baχ'ilɬiɬʲa",
#   "baχil'ub",
#   "baχil'ub",
#   "baħir'iq'alam",
#   "b'eɡi",
#   "bel'eti",
#   "b'eχan",
#   "b'idira",
#   "biz'an",
#   "biz'an",
#   "biz'an",
#   "b'ika",
#   "b'ika",
#   "b'ika",
#   "bisːk'inab",
#   "bisːk'inab",
#   "bisːk'iɬar",
#   "bisːk'iɬar",
#   "bisːk'iɬar",
#   "bisːk'iɬiɬʲa",
#   "bisːm'ilːa",
#   "bisːm'ilːa",
#   'bozi',
#   'boʔojaːzar',
#   "boʔojazartʃ'oː",
#   "buhm'anab",
#   "buhm'aɬar",
#   "buhm'aɬiɬʲa",
#   "buht'anbuhut'an",
#   "bud'un",
#   "bur'awu",
#   "bur'aq'i",
#   "wab'aː",
#   "wab'aː",
#   "wab'ila",
#   "waʕaleːkumsal'am",
#   'wˌaʕza',
#   'wˌaʕza',
#   "wak'il",
#   "wak'il",
#   "w'aq'uba",
#   "w'alːa",
#   "w'alːa",
#   "war'aʕab",
#   "war'aʕiɬar",
#   "war'isi",
#   "wasw'asi",
#   "wasʷ'asijar",
#   "wasʷ'asijar",
#   "wasʷ'asijaːjɬʲa",
#   "wasʷ'asiːɬʲa",
#   "was'iɡʲata",
#   "wat''an",
#   "waħʃ'ijab",
#   "ɡal'ipatɬa",
#   "ɡaːw'ur",
#   "ɡaːw'ur",
#   "ʁaz'awati",
#   "ʁal'at'i",
#   "ʁap'ulɬar",
#   "ʁap'ulɬar",
#   "ʁap'ulɬiɬʲa",
#   "ʁap'ulɬiɬʲa",
#   "ʁarab'aʃi",
#   'ʁˌira',
#   "ʁirm'izi",
#   'hˌawa',
#   'hˌawa',
#   "haw'amutʃu",
#   "hatɬ'ujaːzar",
#   'hˌala',
#   'hˌala',
#   "halaz'ulmu",
#   'hˌamaʁa',
#   "h'amaʁiɬʲar",
#   "hatʃ'ʷ'aːzartʃ'oː",
#   "hatʃ'ʷ'aːzarda",
#   "hatʃ'ʷ'ajazar",
#   "hãd'aq'i",
#   "hˌats'ar",
#   'hohojar',
#   "huʒ'um",
#   "hunː'ar",
#   "hunː'ar",
#   "hunː'ar",
#   "ʕ'abajaɬːiː",
#   "ʕ'abadaɬːiː",
#   "ʕab'asiab'asi",
#   "ʕab'asiab'asi",
#   "ʕad'abad'ab",
#   "ʕad'abqatir",
#   "ʕad'abqatir",
#   'adabqatir',
#   'adabqatir',
#   "ʕ'adulu",
#   "ʕ'adulutɬa",
#   "ʕaʒ'al",
#   "ʕ'aʒanʕalʒ'an",
#   "ʕaʒ'eːbab",
#   "ʕaʒ'eːbab",
#   'ʕaʒeːbɬar',
#   'ʕaʒeːbɬar',
#   'ʕaʒeːbɬar',
#   'ʕaʒeːbɬar',
#   "ʕaʒ'eːbɬiɬʲa",
#   "ʕaʒ'eːbɬiɬʲa",
#   "ʕaʒ'izab",
#   "ʕaʒ'izab",
#   "ʕaʒ'izɬar",
#   "ʕaʒ'uʒimaʒumi",
#   "ʕaz'abʕaq'uba",
#   "ʕ'azanalːahi",
#   "ʕaz'izab",
#   "ʕaj'atab",
#   "ʕaj'ati",
#   "ʕaj'atiʕ'aːti",
#   "ʕajat'ijab",
#   "ʕaj'im",
#   "ʕaj'im",
#   'ʕaːm',
#   'ʕaːm',
#   'ʕaːjb',
#   'ʕaːjb',
#   "ʕaj'imɬar",
#   "ʕ'ajlu",
#   "ʕajm'ijabʕajb'ijaw",
#   "ʕ'aksːa",
#   "ʕaq''il",
#   "ʕaq''ilab",
#   "ʕ'aq'loʕ'aq'ilo",
#   "ʕ'aq'lo",
#   "ʕ'aq'loʕ'aq'ilo",
#   "ʕaq''uba",
#   "ʕaq''ubaq'ʷaraɬar",
#   "ʕal'am",
#   "ʕal'amata",
#   "ʕal'amata",
#   "ʕal'amatab",
#   "ʕal'amateːb",
#   "ʕal'amaɬar",
#   "ʕal'amɬar",
#   "ʕal'amɬiɬa",
#   "ʕal'amaɬiɬʲa",
#   "ʕal'imhek'ʷa",
#   "ʕalimh'ek'ʷa",
#   "ʕalimz'abi",
#   "ʕam'abats'a",
#   "ʕãɡ'urbats'a",
#   "ʕãwubats'a",
#   "ʕam'al",
#   "ʕam'al",
#   "ʕam'al",
#   "ʕam'albetsːan",
#   "ʕ'amːab",
#   "ʕar'aja",
#   "ʕ'arza",
#   "ʕ'arzi",
#   "ʕasː'iʕarabeːji",
#   'ʕaːmʁoli',
#   "ʕ'aːjmɬar",
#   "ʕ'elmu",
#   "ʕ'elmujab",
#   "ʕilː'a",
#   "ʕipr'iti",
#   "ʕipr'iti",
#   "ʕir'aq'awu",
#   "ʕir'aq'awuj",
#   "ʕir'aq'aːji",
#   "ʕ'iʃq'u",
#   "ʕ'umru",
#   "ʕ'umuru",
#   "ʕ'urmi",
#   "d'aʕiba",
#   "d'aʕiba",
#   "d'aʕibatɬa",
#   "daʒ'al",
#   "daʒ'al",
#   "da'imab",
#   "da'imda",
#   "da'imɬar",
#   "da'imɬiɬʲa",
#   'dˌaru',
#   'dˌaru',
#   "dar'uɬar",
#   "dar'uɬiɬʲa",
#   'dˌarutɬa',
#   "d'artsːi",
#   'dʷaː',
#   'dʷaː',
#   'dˌibir',
#   'dˌibir',
#   "diw'abeɡ",
#   'din',
#   "din'ijab",
#   "dun'eːl",
#   "dun'eːl",
#   "dun'eːl",
#   "dun'eːlʕalam",
#   "dun'eːlɬːiqa",
#   "dur'usab",
#   "dur'usab",
#   "dur'usab",
#   "dʒaw'ab",
#   "dʒaw'ab",
#   "dʒawab'ijab",
#   "dʒah'ilab",
#   "dʒ'ahlu",
#   "dʒ'azma",
#   "dʒam'aːta",
#   'dʒanʒan',
#   'dʒanʒan',
#   "dʒan'aza",
#   "dʒãsː'usː",
#   "dʒ'eniʒ'eni",
#   "dʒ'ildi",
#   "ʒawh'ar",
#   "zaw'al",
#   "zah'irab",
#   "zah'irab",
#   "zah'irda",
#   "zah'irihar",
#   "zah'irihiɬʲa",
#   "zah'irɬar",
#   "zah'irɬiɬʲa",
#   "z'ahru",
#   "zahurm'an",
#   "zaʕib'ab",
#   "zaʕib'abrak'ʷatɬa",
#   "zaʕ'ibihiɬʲa",
#   "zaʕ'ibɬar",
#   "zaʕ'ibɬar",
#   "zaʕ'ibɬiɬʲa",
#   "zaʕ'ibɬiɬʲa",
#   "zak'aːta",
#   "zak'unijab",
#   "zaq''um",
#   "zal'imab",
#   "zal'imab",
#   "zam'an",
#   "zar'al",
#   "zaral'ijab",
#   "zaħm'aɬar",
#   "zaħm'aɬiɬʲa",
#   "zaħm'aɬiɬʲa",
#   "zaħm'aɬiɬʲa",
#   "zaħm'atab",
#   "zaħm'atab",
#   "zaħm'atab",
#   "zaħm'ati",
#   "zij'anzaral",
#   'zˌina',
#   "zin'aχat'a",
#   "zulq'arn'aj",
#   "z'ulmu",
#   "z'ulmuɬiː",
#   "zur'iɡata",
#   'zˌurma',
#   "zurm'aqan",
#   "zuħm'ati",
#   "id'ara",
#   "iʒ'ara",
#   "izb'atʃi",
#   "izb'atʃi",
#   "iq'ib'al",
#   "ilːalab'ilːalatɬ'o",
#   "ilb'isi",
#   "ilb'isi",
#   "im'am",
#   "im'an",
#   "im'an",
#   "imtiħ'an",
#   "ins'an",
#   "insan'ijab",
#   "ins'anhajam",
#   "insan'ijata",
#   "ins'ap",
#   "ins'ap",
#   "ins'apab",
#   'ˌitu',
#   "iχtij'ar",
#   "iχtil'ati",
#   "iʃ'ara",
#   "iʃk'al",
#   "ĩʒ'il",
#   "ĩq'il'ab",
#   "ĩtɬ'iazar",
#   'ja',
#   'ja',
#   'jˌabu',
#   "jaq''uti",
#   "jar'aʁi",
#   "j'aħalamusi",
#   "kaʁ'ati",
#   "kaʁ'ati",
#   "kaʁ'ati",
#   "kaʁ'ati",
#   "kal'am",
#   "kal'am",
#   "k'amijalar",
#   "k'amijar",
#   "k'amijar",
#   "k'amijaːjɬʲa",
#   "kam'ilab",
#   "kam'ilab",
#   "kam'ilɬar",
#   "kam'ilɬiɬʲa",
#   "kam'itar",
#   "k'amiːɬʲa",
#   "k'amiːɬʲa",
#   "kan'awu",
#   "kap'urdabitʃ'ab",
#   "kap'urɬar",
#   "kap'urɬiɬʲa",
#   'kardon',
#   "kar'oːti",
#   "kat'uʃka",
#   "katʃ'itʃi",
#   "kaʃ'iʃ",
#   "k'aːba",
#   "k'epi",
#   "k'epi",
#   'kˌila',
#   "kil'isa",
#   "kiʃm'iʃ",
#   "kum'aki",
#   "kʲ'aʃːa",
#   "q'ab'iħab",
#   "q'ab'iħab",
#   "q'ab'iħihar",
#   "q'ab'iħihiɬʲa",
#   "q'ab'iħiɬar",
#   "q'ab'iħiɬar",
#   "q'ab'iħiɬiɬʲa",
#   "q'ab'ulab",
#   "q'ab'ulab",
#   "q'ab'ulihar",
#   "q'ab'ulihar",
#   "q'ab'ulihiɬʲa",
#   "q'ah'arihar",
#   "q'ah'arihiɬʲa",
#   "q'ad'ar",
#   "q'ad'arq'aj'ar",
#   "q''adru",
#   "q''adruq'imatatɬa",
#   "q''adruq'imatatɬa",
#   "q''aja",
#   "q''aja",
#   "q'aj'abatɬa",
#   "q''aji",
#   "q''aji",
#   "q'ajs'ar",
#   "q'ajs'ar",
#   "q'al'am",
#   "q'al'at'ar",
#   "q'am",
#   "q'an'aʕaɬar",
#   "q'an'aʕaɬar",
#   "q'an'aʕata",
#   "q'an'aʕatab",
#   "q'an'aʕatiɬiɬʲa",
#   "q''arzitɬa",
#   "q''arziɬːila",
#   "q''asːi",
#   "q''asːi",
#   "q'at''ipa",
#   "q'at''ipa",
#   "q'at''ib",
#   "q'at''ib",
#   "q''imata",
#   "q''imata",
#   "q''imata",
#   "q''imata",
#   "q''imatitɬa",
#   "q''imatitɬa",
#   "q'ir'al",
#   "q''isːa",
#   "q'or'am",
#   "q''ubata",
#   "q''ubatab",
#   "kʲ''eazar",
#   "kʲ'il'ikʲ'a",
#   "l'ahdu",
#   "laz'atab",
#   "laz'atab",
#   "laz'ati",
#   "lam'usi",
#   "lam'usiɬar",
#   "lam'usiɬiɬʲa",
#   "lãq'il'aq'i",
#   "maʁr'ib",
#   "maʕan'amaʕn'a",
#   "maʕan'amaʕn'a",
#   "maʕan'amaʕn'a",
#   "maʕd'an",
#   "maʕ'iʃata",
#   "maʕn'eːtɬa",
#   "maʕn'eːtɬa",
#   "maʕn'eːtɬa",
#   "madr'as",
#   "maq''ala",
#   "maq'alat''isi",
#   "maq'alat''isi",
#   "mak'al'aʃka",
#   "makʲ'azaman",
#   "malʕ'un",
#   "m'asalaː",
#   "mas'ala",
#   "mas'ala",
#   "masʔ'ala",
#   "masʔ'ala",
#   "masr'aːta",
#   "masq'ara",
#   "masq'araχːutʃ'i",
#   "maχl'uq'",
#   "maħ'al",
#   "maħr'umihiɬʲa",
#   "maħr'umɬar",
#   "maħr'umɬiɬʲa",
#   "maʃr'iq'",
#   "m'aʃtar",
#   "maʃχ'al",
#   "maʃχ'altɬa",
#   "m'aːʃalːah",
#   "mãz'il",
#   'merk',
#   "m'erkab",
#   "miʕm'ati",
#   "meʕm'ati",
#   "milː'atimin'ati",
#   "mis'al",
#   "misal'ijab",
#   "miħm'ar",
#   "m'uhru",
#   "m'uhru",
#   "muʕal'im",
#   "muq's'anab",
#   "muq's'ahar",
#   "muq's'ahiɬʲa",
#   "muq's'aɬar",
#   "muq's'aɬar",
#   "muq's'aɬiɬʲa",
#   "munap'iq'i",
#   "mup'aʕata",
#   "muk'aʕata",
#   "mup'aʕatab",
#   "muk'aʕat'ab",
#   "mur'aji",
#   "mur'aji",
#   "mur'id",
#   "mustaħ'iq'ab",
#   "mustaħ'iq'ab",
#   "mut'aːl",
#   "mut''iʕab",
#   "mut''iʕab",
#   "mut''iʕihar",
#   "mut''iʕihar",
#   "mut''iʕihiɬʲa",
#   "mut''iʕihiɬʲa",
#   "mut''iʕiɬar",
#   "mut''iʕiɬiɬʲa",
#   "muħarr'ambotsːu",
#   "muχb'ir",
#   "muħk'anab",
#   "muħk'anab",
#   "muħk'anab",
#   "muħk'anab",
#   "muħk'anihiɬʲa",
#   "muħk'anihiɬʲa",
#   'muħkʲãhar',
#   'muħkʲãhar',
#   'muħkãda',
#   'muħkãda',
#   'muħkãda',
#   "muħk'aɬar",
#   "muħk'aɬar",
#   "muħk'aɬar",
#   "muħk'aɬiɬʲa",
#   "muħk'aɬiɬʲa",
#   "muʔm'inab",
#   'muʔmĩɬar',
#   "naʕan'a",
#   "nadʒ'asːi",
#   "n'azmu",
#   "n'azru",
#   "n'aq'iʃi",
#   "nam'usjaħa",
#   "nap'aq'a",
#   "n'arti",
#   "n'arti",
#   "n'aslu",
#   'nasru',
#   "nasː'iħata",
#   "nasː'iħata",
#   'naːw',
#   "n'iɡʲata",
#   "niʕm'ati",
#   "niʕm'ati",
#   "niχ'ak'i",
#   "nuʁal'ejiː",
#   "nuk'ar",
#   'nur',
#   "n'uħub",
#   "n'uħub",
#   "p'ahʷma",
#   "p'ahʷma",
#   "p'ahimu",
#   "p'ahimu",
#   "p'aja",
#   "pajd'a",
#   "paq''ir",
#   "paq''ir",
#   "paq''irab",
#   'pal',
#   "pal'aχan",
#   "pal'aχãɬar",
#   "pan'aduneːl",
#   "pan'aɬar",
#   "papr'uzi",
#   "par'aq'aɬar",
#   "par'aq'ata",
#   "par'aq'ata",
#   "par'aq'atab",
#   "par'asːi",
#   "par'aɡa",
#   "par'aɡaːji",
#   "pard'aw",
#   "pard'aw",
#   "p'arzi",
#   "par'izːab",
#   "p'artu",
#   'pˌartʃa',
#   "partʃ'aħi",
#   "partʃ'aħi",
#   "pas'aki",
#   "pas'aki",
#   "pas'atab",
#   "pas'atihar",
#   "pas'atihiɬʲa",
#   "pas'atiɬar",
#   "pas'atiɬar",
#   "pas'atiɬiɬʲa",
#   "pas'atiɬiɬʲa",
#   "pasː'iħab",
#   "pasː'iħab",
#   "pasː'iħiɬar",
#   "patiʃ'aha",
#   "pat'ika",
#   "paturm'an",
#   "paturm'an",
#   "p'aʃa",
#   "paʃl'uqi",
#   "pãd'ur",
#   "p'ikuru",
#   "pikurut'ub",
#   "p'il",
#   "pilp'il",
#   "pirʕ'an",
#   "pirʕ'an",
#   'porma',
#   "pul'aw",
#   "pul'aw",
#   "p'urtʃi",
#   "p'uti",
#   "radʒ'abotsːu",
#   "raz'iraz'eːb",
#   "raz'iraz'eːb",
#   "raz'ihar",
#   "raz'ihiɬʲa",
#   "raz'ihiɬʲa",
#   "raz'ijab",
#   "raz'ijab",
#   "raz'iɬar",
#   "raz'iɬiɬʲa",
#   "raħ'atab",
#   "raħ'ati",
#   "raħ'atilaːqa",
#   'raħatiɬaːqa',
#   "r'aħmu",
#   'rˌiba',
#   "r'iziq'a",
#   "riʃʷ'ati",
#   "r'uzma",
#   "ruzm'aj",
#   "ruzm'ajzebu",
#   "rua'umãɬar",
#   "rua'umãɬiɬʲa",
#   "r'uħil",
#   "r'uħil",
#   "r'uħilħaltɬisːa",
#   "ruħtʃ''aɡoɬar",
#   "sab'awsab'ab",
#   "sab'awsab'ab",
#   "sab'awsab'ab",
#   "s'aʁab",
#   "s'aʁsalamata",
#   "s'aʁsalamata",
#   "s'aχsalamata",
#   "s'aχsalamata",
#   "saχʷ'atab",
#   "saχʷ'atiɬar",
#   "saχʷ'atiɬiɬʲa",
#   "saq'ati",
#   "saq'ati",
#   "s'ebq'ajatɬa",
#   "s'ebq'ajaqa",
#   "su'al",
#   "su'al",
#   "sum'awur",
#   "sːaʕ'ati",
#   "sːaʕ'ati",
#   "sːaj'aq'a",
#   "sː'ajʁata",
#   "sːal'am",
#   "sːal'amatab",
#   "sːal'amatab",
#   "sːal'amatiɬaːqa",
#   "sːap'ar",
#   "sːap'in",
#   "sː'apur",
#   "sː'apurab",
#   "sː'apurɬaːqa",
#   "sːarʒ'in",
#   "sːʷ'ardar",
#   "sː'etka",
#   "sːij'aħi",
#   "sːim'iti",
#   "sːip'ati",
#   "sːip'atisːurati",
#   "sː'iħuru",
#   'sːˌuʒda',
#   "sːur'ati",
#   "sːur'ati",
#   "t'awba",
#   "tawkː'al",
#   "tawkː'al",
#   "tawkː'alab",
#   "tawkː'alab",
#   "tadib'ir",
#   "tadib'ir",
#   "tadib'irab",
#   "tadib'irab",
#   "takr'arihar",
#   "takr'arihiɬʲa",
#   "taq''eja",
#   "taq''eja",
#   "taq'sː'ir",
#   "taq'sːirab",
#   "tam'akur",
#   "tam'atʃa",
#   "tam'aʃa",
#   "tam'aʃaɬar",
#   "tam'aʃaɬiɬʲa",
#   "tamaʃ'eːb",
#   "tarb'ija",
#   "t'arzi",
#   "t'arziːjob",
#   "tar'iχi",
#   "tar'iχi",
#   "tast'iq'ihar",
#   "tast'iq'ihiɬʲa",
#   "tasːam'aħab",
#   "tasːam'aħiɬar",
#   "tasːam'aħiɬo",
#   "t'aχi",
#   "t'aχi",
#   "t'aχʃahar",
#   'toki',
#   'toki',
#   "tuk'an",
#   "tum'an",
#   "tuχ'um",
#   "t'uʃːaːji",
#   "tuʃm'an",
#   "tuʃmãɬ'ar",
#   "t'ab'aʕata",
#   "t'ab'aʕata",
#   "t'abiʕ'ijab",
#   "t'aw'usi",
#   "t'aw'usi",
#   "t'aʕ'am",
#   "t'aʕ'am",
#   "t'aʕam'ijoːb",
#   "t'aʕ'im",
#   "t'aʕ'im",
#   "t'al'ab",
#   "t'al'ab",
#   "t'al'am",
#   "t'al'am",
#   "t'ar'iq'",
#   'ˌuʒuru',
#   "ukra'inaw",
#   "ukra'inaj",
#   "ukra'inaw",
#   "um'umadi",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "ust'ar",
#   "χaj'ir",
#   'χaːjr',
#   "χaj'irijoːb",
#   "χ'ajrkʲ'aː",
#   "χalb'ati",
#   "χ'alq'i",
#   "χ'alq'i",
#   "χalq''ijab",
#   'χan',
#   "χas'eːta",
#   "χ'asːab",
#   "χ'asːab",
#   "χ'asːab",
#   "χat''a",
#   "χ'aːjrhikʲ'ub",
#   "χ'aɬar",
#   "χʷaʒ'ain",
#   "χʷaʒ'ain",
#   "χij'alχiw'al",
#   "χij'alχiw'al",
#   "χij'alχiw'al",
#   "χijalq''asːi",
#   "χij'anaɬar",
#   "χij'anatab",
#   "χin'eːtab",
#   "χːab'ar",
#   "χːab'ar",
#   "χːab'ar",
#   "χːab'ar",
#   "χːab'artɬa",
#   "χːab'arkalam",
#   "χːab'arq'uw",
#   "χːab'arule",
#   "χːab'atʃ'abar",
#   "χːaz'ina",
#   "χːaz'ina",
#   "χːaz'ina",
#   "χːam'iz",
#   "χː'at'i",
#   'χːorma',
#   'χːˌurda',
#   'χːˌurda',
#   "qaz'an",
#   "qaz'aqi",
#   "q'azioːtʃa",
#   "qal'a",
#   "qal'a",
#   "qal'a",
#   "q'alab",
#   "q'alahar",
#   "q'alaɬar",
#   "qal'ijan",
#   "qal'ijan",
#   "qar'awuqar'awul",
#   "qar'awuqar'awul",
#   "qar'awuqar'awul",
#   "qar'awuɬar",
#   "qarm'uzi",
#   'qˌaħba',
#   "qaħb'aɬiɬʲa",
#   "qaħb'ijab",
#   "qaħib'aɬar",
#   "qul'uqi",
#   "qurũsː'aqi",
#   "qũd'aʁi",
#   "ħaw'an",
#   "ħaw'an",
#   "ħaw'an",
#   "ħaʒ'aɬar",
#   "ħaʒ'aɬiɬʲa",
#   "ħaʒ'atab",
#   "ħaʒatχ'an",
#   "ħaʒ'iːsab",
#   'χaʒiːsab',
#   "ħajr'anab",
#   "ħak'im",
#   "ħak'im",
#   "ħak'imɬar",
#   "ħak'imɬar",
#   "ħ'aq'ab",
#   "ħ'aq'i",
#   "ħaq''iq'atiɬːila",
#   "ħaq'iq''ijab",
#   "ħaq''irab",
#   "ħaq''irab",
#   "ħaq''irhar",
#   "ħaq''irihiɬʲa",
#   "ħaq''irɬar",
#   "ħaq''irɬiɬʲa",
#   'ħal',
#   'ħal',
#   "ħal'al",
#   "ħal'alab",
#   "ħal'alab",
#   "ħal'alhar",
#   "ħal'ilab",
#   "ħal'imab",
#   "ħal'imɬar",
#   'ħalimɬiɬʲa',
#   "ħ'alħukmu",
#   "ħam'abahadur",
#   "ħam'abahadurɬar",
#   "ħam'alaw",
#   "ħamar'e",
#   "ħar'akatbaqiːɬʲa",
#   "ħar'amɬar",
#   "ħ'arpi",
#   "ħasː'il",
#   "ħasː'il",
#   "ħikm'atihiɬʲa",
#   "ħikm'atab",
#   "ħ'ilːa",
#   "ħilːan'akur",
#   "ħilːam'akru",
#   "ħis'ab",
#   "ħis'ab",
#   "ħis'ab",
#   "ħis'abdiː",
#   "ħis'absual",
#   "ħisakit'ab",
#   "ħuʒ'a",
#   "ħ'uʒru",
#   "ħ'uʒru",
#   "ħ'ukmu",
#   "ħuk'umati",
#   "ħur'iɡata",
#   "ħur'iɡata",
#   "ħuriʕ'an",
#   "ħurm'ati",
#   "ħurm'ati",
#   "tsuχ'ari",
#   "tsːiɡ'anaw",
#   "tʃajd'antʃaj'an",
#   "tʃaj'ir",
#   "tʃak'ar",
#   "tʃap'ar",
#   "tʃap'ar",
#   "tʃarm'a",
#   "tʃ'aχi",
#   "tʃ'arχi",
#   'tʃˌini',
#   "tʃir'aqi",
#   "tʃ'iti",
#   'tʃorti',
#   "tʃ'urpa",
#   "tʃ'urpa",
#   'tʃorpa',
#   'tʃorpa',
#   "tʃ''atʃ'a",
#   "ʃaw'albotsːu",
#   "ʃ'ahaw",
#   "ʃah'ar",
#   "ʃah'ar",
#   "ʃah'id",
#   "ʃaʕm'anbotsːu",
#   'ʃal',
#   "ʃam'ati",
#   "ʃam'atizebu",
#   "ʃap'aʕata",
#   "ʃap'aq'ata",
#   "ʃarb'al",
#   'ʃarʕ',
#   "ʃar'iʕata",
#   "ʃarʕ'ijab",
#   "ʃ'art'i",
#   'ʃˌiʃa',
#   "ʃːajt''an",
#   "ʃːajt''an",
#   "ʃːajt''anab",
#   "ʃːajt''aɬar",
#   "ʃː'akab",
#   "ʃː'akijar",
#   "ʃː'akijar",
#   "ʃː'akijar",
#   "ʃː'akiːɬʲa",
#   "ʃː'akiːɬʲa",
#   "ʃː'akiːɬʲa",
#   "ʃː'aχːi",
#   "ʃː'aχːi",
#   "ʃː'aχːi",
#   'ʃːotab',
#   "ʃː'ukuru"],
#  'toki1238': ["aχirarb'aʕ"]}

# %%
lexstat_df = pd.read_csv('res_ls.qlc', sep='\t', skiprows=7)
# удаляем ранее добавленные значения
lexstat_df = lexstat_df[lexstat_df['IPA'] != 'aaa']

# %%
grouped_df = lexstat_df.groupby('COGNATES').apply(lambda x: x.assign(CONCEPT=x['CONCEPT'] + '_' + x['COGNATES'].astype(str)))
grouped_df['IPA'] = grouped_df['IPA'].astype(str)

result_df = grouped_df.groupby(['CONCEPT', 'DOCULECT'])['IPA'].agg(lambda x: ', '.join(x)).unstack().reset_index()
result_df
# Out:
# DOCULECT                                            CONCEPT  akhv1239  \
# 0         (в соч. с инф. выражает обязательность действи...       NaN
# 1                                   (возглас (петухом)_11.0       NaN
# 2                                     (возглас вызова)_20.0       NaN
# 3                 (возглас недовольствия и недоумения)_29.0       NaN
# 4                                  (возглас одобрения)_38.0       NaN
# ...                                                     ...       ...
# 32126                                       ящичек_233538.0       NaN
# 32127                                       ящичек_233544.0       NaN
# 32128                            ящур (у животных)_233570.0       NaN
# 32129                                         ящур_233555.0  j'aʃːuri
# 32130                                         ящур_233557.0       NaN
#
# DOCULECT andi1255 bagv1239 botl1242 cham1309 ghod1238   kara1474 tind1238  \
# 0             NaN      NaN      NaN      NaN      NaN  bekːʷ'aɬa      NaN
# 1          ɢuɢudu      NaN      NaN      NaN      NaN        NaN      NaN
# 2            mp'o      NaN      NaN      NaN      NaN        NaN      NaN
# 3         wep'ero      NaN      NaN      NaN      NaN        NaN      NaN
# 4          hajhuj      NaN      NaN      NaN      NaN        NaN      NaN
# ...           ...      ...      ...      ...      ...        ...      ...
# 32126      ʁutuqi      NaN      NaN      NaN      NaN      oʔ'ol      NaN
# 32127         NaN      NaN      NaN      NaN      NaN        NaN    ʁˌoru
# 32128         NaN      NaN      NaN      NaN      NaN   t'aːlahu      NaN
# 32129         NaN      NaN  j'aʃːur      NaN  j'aʃːur    jaʃː'ur      NaN
# 32130         NaN    k'era      NaN      NaN      NaN        NaN    k'eri
#
# DOCULECT toki1238
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 32126         NaN
# 32127         NaN
# 32128         NaN
# 32129         NaN
# 32130         NaN
#
# [32131 rows x 10 columns]

# %%
result_df[result_df['toki1238'].notna()]
# Out:
# DOCULECT                             CONCEPT akhv1239 andi1255 bagv1239  \
# 512       агьаᴴдоб, бокьидоб, къардоб_4194.0      NaN      NaN      NaN
# 1539                   болезнь копыт_11709.0      NaN      NaN      NaN
# 4770                        г|акъраб_35082.0      NaN      NaN      NaN
# 8800                злополучный день_64584.0      NaN      NaN      NaN
# 26009                 сл/.байбихьар_189801.0      NaN      NaN      NaN
# 28600                        тополь_208417.0      NaN      NaN      NaN
#
# DOCULECT botl1242 cham1309 ghod1238 kara1474 tind1238    toki1238
# 512           NaN      NaN      NaN      NaN      NaN      itʃ'ib
# 1539          NaN      NaN      NaN      NaN      NaN    χĩχiledu
# 4770          NaN      NaN      NaN      NaN      NaN   itʃ'ik'al
# 8800          NaN      NaN      NaN      NaN      NaN  aχirarb'aʕ
# 26009         NaN      NaN      NaN      NaN      NaN      baʃl'a
# 28600         NaN      NaN      NaN      NaN      NaN  besad'iril

# %%
# видим, что в токитинском нет когнатов, поэтому удаляем информацию для токитинского

result_df.drop('toki1238', axis=1, inplace=True)
result_df = result_df[result_df.notna().sum(axis=1) > 1]

# %%
result_df[37:47]
# Out:
# DOCULECT                                            CONCEPT akhv1239 andi1255  \
# 37                  (возглас, которым отгоняют кошек)_319.0      NaN      NaN
# 38                    (возглас, которым отгоняют кур)_325.0    ɡ'ure      NaN
# 39                   (возглас, которым отгоняют овец)_337.0      NaN      NaN
# 40                   (возглас, которым отгоняют овец)_341.0      NaN      NaN
# 41                   (возглас, которым отгоняют осла)_348.0      NaN      NaN
# 42                  (возглас, которым отгоняют собак)_354.0      NaN      NaN
# 43                (возглас, которым отгоняют теленка)_364.0      NaN      NaN
# 44                  (возглас, которым отгоняют телят)_376.0      NaN      NaN
# 45        (возглас, которым отгоняют, подгоняют коров)_3...      NaN      NaN
# 46        (возглас, которым отгоняют, понукают коров)_391.0      NaN      NaN
#
# DOCULECT  bagv1239 botl1242 cham1309   ghod1238 kara1474 tind1238
# 37             NaN  tʃːit'a      NaN        NaN      NaN      NaN
# 38         kurʕ'aj      kuʃ      NaN  ɡureɡ'ure   ɡur'aj   kur'aː
# 39             NaN  tsːit'a   tsiraj       ʕats   ʕ'eʃaj      NaN
# 40             NaN      NaN      NaN        NaN      NaN    k'eri
# 41             NaN      NaN      NaN    q''oʃːu      NaN      NaN
# 42        dʒ'ebeɬi      NaN      NaN        NaN      NaN      NaN
# 43             NaN     huts      NaN    ʕ'arija      NaN      NaN
# 44             NaN      NaN      NaN        NaN   ʕel'aj      NaN
# 45             NaN      ʕaj      NaN        NaN      NaN      NaN
# 46             NaN    hiz'o      NaN        NaN      NaN      NaN

# %%
def masking(x):
  if type(x) == str:
    return 1
  else:
    return 0

stat_cognates = result_df.reset_index()
stat_cognates.drop('index', axis=1, inplace=True)
stat_cognates = stat_cognates.applymap(masking)
stat_cognates = stat_cognates.T.dot(stat_cognates)
stat_cognates
# Out:
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/3543790557.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   stat_cognates = stat_cognates.applymap(masking)
# DOCULECT  CONCEPT  akhv1239  andi1255  bagv1239  botl1242  cham1309  ghod1238  \
# DOCULECT
# CONCEPT     32125      8391      6231      7763     12367      6016      5422
# akhv1239     8391      8391      1328      2858      2691      2259      2152
# andi1255     6231      1328      6231      1353      1831      1148      1282
# bagv1239     7763      2858      1353      7763      2987      2769      2419
# botl1242    12367      2691      1831      2987     12367      2433      3292
# cham1309     6016      2259      1148      2769      2433      6016      2325
# ghod1238     5422      2152      1282      2419      3292      2325      5422
# kara1474     5192      2468      1145      2139      2227      1933      2004
# tind1238     7527      2828      1283      3549      2601      2723      2113
#
# DOCULECT  kara1474  tind1238
# DOCULECT
# CONCEPT       5192      7527
# akhv1239      2468      2828
# andi1255      1145      1283
# bagv1239      2139      3549
# botl1242      2227      2601
# cham1309      1933      2723
# ghod1238      2004      2113
# kara1474      5192      2007
# tind1238      2007      7527

# %%
directory = 'output_html'
os.makedirs(directory, exist_ok=True)

stat_cognates = stat_cognates.to_html()
with open('output_html/stat_cognates.html', 'w') as f:
    f.write(stat_cognates)

# %%
# добавляем отдельные столбцы для записи CV (и CV без согласных r,l,m,n,w,j,b)

result_df = result_df.reindex(columns = result_df.columns.tolist() + 
                                ['kara_cv', 'kara_rlm','botl_cv', 'botl_rlm', 'akhv_cv', 'akhv_rlm', 
                                 'ghod_cv', 'ghod_rlm', 'andi_cv', 'andi_rlm', 'cham_cv', 'cham_rlm', 
                                 'tind_cv', 'tind_rlm', 'bagv_cv', 'bagv_rlm', 'bor'])
result_df = result_df[['CONCEPT', 'kara1474', 'kara_cv', 'kara_rlm', 'botl1242', 'botl_cv', 'botl_rlm', 
                       'akhv1239', 'akhv_cv', 'akhv_rlm', 'ghod1238', 'ghod_cv', 'ghod_rlm', 
                       'andi1255', 'andi_cv', 'andi_rlm', 'cham1309', 'cham_cv', 'cham_rlm', 
                       'tind1238', 'tind_cv', 'tind_rlm', 'bagv1239', 'bagv_cv', 'bagv_rlm', 'bor']]

# заполняем столбцы заимствования и CV

for index, row in result_df.iterrows():
    for i in range(1, len(row)-3, 3):
        if row[-1] != 1 and not(pd.isna(row[i])) and row[i] in bor_dict[list(result_df.columns)[i]]:
            result_df.loc[index, 'bor'] = 1
        if not(pd.isna(row[i])):
            result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
            result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
result_df
# Out:
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[-1] != 1 and not(pd.isna(row[i])) and row[i] in bor_dict[list(result_df.columns)[i]]:
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if not(pd.isna(row[i])):
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CVCVCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'bVCVCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CVCVCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CVCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'wVCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'VCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'VCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CVCCVC' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+1]] = letters_to_CV(row[i], v, c, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CVCCVC' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1074307980.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'CVCV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[index, list(result_df.columns)[i+2]] = letters_to_CV(row[i], v, c_sans_rlmnwjb, list(result_df.columns)[i])
# DOCULECT                                            CONCEPT   kara1474  \
# 0         (в соч. с инф. выражает обязательность действи...  bekːʷ'aɬa
# 1                                   (возглас (петухом)_11.0        NaN
# 2                                     (возглас вызова)_20.0        NaN
# 3                 (возглас недовольствия и недоумения)_29.0        NaN
# 4                                  (возглас одобрения)_38.0        NaN
# ...                                                     ...        ...
# 32126                                       ящичек_233538.0      oʔ'ol
# 32127                                       ящичек_233544.0        NaN
# 32128                            ящур (у животных)_233570.0   t'aːlahu
# 32129                                         ящур_233555.0    jaʃː'ur
# 32130                                         ящур_233557.0        NaN
#
# DOCULECT kara_cv kara_rlm botl1242 botl_cv botl_rlm  akhv1239 akhv_cv  \
# 0         CVCVCV   bVCVCV      NaN     NaN      NaN       NaN     NaN
# 1            NaN      NaN      NaN     NaN      NaN       NaN     NaN
# 2            NaN      NaN      NaN     NaN      NaN       NaN     NaN
# 3            NaN      NaN      NaN     NaN      NaN       NaN     NaN
# 4            NaN      NaN      NaN     NaN      NaN       NaN     NaN
# ...          ...      ...      ...     ...      ...       ...     ...
# 32126       VCVC     VCVl      NaN     NaN      NaN       NaN     NaN
# 32127        NaN      NaN      NaN     NaN      NaN       NaN     NaN
# 32128     CVCVCV   CVlVCV      NaN     NaN      NaN       NaN     NaN
# 32129      CVCVC    jVCVr  j'aʃːur   CVCVC    jVCVr  j'aʃːuri  CVCVCV
# 32130        NaN      NaN      NaN     NaN      NaN       NaN     NaN
#
# DOCULECT akhv_rlm  ... cham1309 cham_cv cham_rlm tind1238 tind_cv tind_rlm  \
# 0             NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 1             NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 2             NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 3             NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 4             NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# ...           ...  ...      ...     ...      ...      ...     ...      ...
# 32126         NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 32127         NaN  ...      NaN     NaN      NaN    ʁˌoru    CVCV     CVrV
# 32128         NaN  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 32129      jVCVrV  ...      NaN     NaN      NaN      NaN     NaN      NaN
# 32130         NaN  ...      NaN     NaN      NaN    k'eri    CVCV     CVrV
#
# DOCULECT bagv1239 bagv_cv bagv_rlm  bor
# 0             NaN     NaN      NaN  NaN
# 1             NaN     NaN      NaN  NaN
# 2             NaN     NaN      NaN  NaN
# 3             NaN     NaN      NaN  NaN
# 4             NaN     NaN      NaN  NaN
# ...           ...     ...      ...  ...
# 32126         NaN     NaN      NaN  NaN
# 32127         NaN     NaN      NaN  NaN
# 32128         NaN     NaN      NaN  NaN
# 32129         NaN     NaN      NaN  1.0
# 32130       k'era    CVCV     CVrV  NaN
#
# [32125 rows x 26 columns]

# %%
result_df.to_csv('grouped_data.csv', index=False)

# %% [markdown]
# ### 3.4. Попарное сравнение языков

# %%
# преобразуем result_df в фрейм данных со структурой язык1-фонемы1-CV1-язык2-фонемы2-CV2-значение-заимствование

def pairwise_comparison(df):
    data_res = {
        'language1': [],
        'value1': [],
        'value1_cv': [],
        'value1_rlm': [],
        'language2': [],
        'value2': [],
        'value2_cv': [],
        'value2_rlm': [],
        'meaning': [],
        'bor': []
    }
    
    for index, row in df.iterrows():
        for i in range(1, len(row)-3, 3):
            for j in range(i+3, len(row)-3, 3):
                if not(pd.isna(row[i]) or pd.isna(row[j])):
                    data_res['meaning'].append(row[0])
                    data_res['language1'].append(df.columns[i])
                    data_res['value1'].append(row[i])
                    data_res['value1_cv'].append(s_to_syllables(row[i+1]))
                    data_res['value1_rlm'].append(row[i+2])
                    data_res['language2'].append(df.columns[j])
                    data_res['value2'].append(row[j])
                    data_res['value2_cv'].append(s_to_syllables(row[j+1]))
                    data_res['value2_rlm'].append(row[j+2])
                    if row[-1] == 1:
                        data_res['bor'].append(1)
                    else:
                        data_res['bor'].append('')
            
    data_res = pd.DataFrame(data_res)
    return data_res

# %%
pairwise_comparison_df = pairwise_comparison(result_df)
pairwise_comparison_df
# Out:
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if not(pd.isna(row[i]) or pd.isna(row[j])):
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['meaning'].append(row[0])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['value1'].append(row[i])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['value1_cv'].append(s_to_syllables(row[i+1]))
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['value1_rlm'].append(row[i+2])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['value2'].append(row[j])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['value2_cv'].append(s_to_syllables(row[j+1]))
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_res['value2_rlm'].append(row[j+2])
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/1961309398.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[-1] == 1:
#       language1       value1  value1_cv value1_rlm language2    value2  \
# 0      kara1474          ʕaj        CVC        CVj  andi1255       wej
# 1      cham1309         susu      CV-CV       CVCV  bagv1239       sːu
# 2      ghod1238       hoːh'a      CV-CV       CVCV  andi1255      woha
# 3      kara1474  q'oːʃːikj'a  CV-CVC-CV    CVCVCjV  botl1242     q'oʃː
# 4      kara1474  q'oːʃːikj'a  CV-CVC-CV    CVCVCjV  akhv1239  q'ː'oʃːo
# ...         ...          ...        ...        ...       ...       ...
# 62142  kara1474      jaʃː'ur     CV-CVC      jVCVr  ghod1238   j'aʃːur
# 62143  botl1242      j'aʃːur     CV-CVC      jVCVr  akhv1239  j'aʃːuri
# 62144  botl1242      j'aʃːur     CV-CVC      jVCVr  ghod1238   j'aʃːur
# 62145  akhv1239     j'aʃːuri   CV-CV-CV     jVCVrV  ghod1238   j'aʃːur
# 62146  tind1238        k'eri      CV-CV       CVrV  bagv1239     k'era
#
#       value2_cv value2_rlm                                       meaning bor
# 0           CVC        wVj                                (возглас)_74.0
# 1            CV         CV   (возглас, которым науськивают собаку)_192.0
# 2         CV-CV       wVCV  (возглас, которым останавливают быков)_200.0
# 3           CVC        CVC   (возглас, которым останавливают осла)_246.0
# 4         CV-CV       CVCV   (возглас, которым останавливают осла)_246.0
# ...         ...        ...                                           ...  ..
# 62142    CV-CVC      jVCVr                                 ящур_233555.0   1
# 62143  CV-CV-CV     jVCVrV                                 ящур_233555.0   1
# 62144    CV-CVC      jVCVr                                 ящур_233555.0   1
# 62145    CV-CVC      jVCVr                                 ящур_233555.0   1
# 62146     CV-CV       CVrV                                 ящур_233557.0
#
# [62147 rows x 10 columns]

# %%
pairwise_comparison_df[50004:50010]
# Out:
#       language1      value1  value1_cv value1_rlm language2           value2  \
# 50004  cham1309    bˌetitla  CV-CVC-CV    bVCVClV  bagv1239        bet'etila
# 50005  kara1474  bets'ː'aɬa   CV-CV-CV     bVCVCV  botl1242  b'uts'ːats'ːaɬi
# 50006  kara1474  bets'ː'aɬa   CV-CV-CV     bVCVCV  akhv1239   b'et'iloːrutɬa
# 50007  kara1474  bets'ː'aɬa   CV-CV-CV     bVCVCV  ghod1238          butsː'i
# 50008  kara1474  bets'ː'aɬa   CV-CV-CV     bVCVCV  cham1309         bˌus'ːla
# 50009  kara1474  bets'ː'aɬa   CV-CV-CV     bVCVCV  tind1238       bˌutsːiɬʲa
#
#              value2_cv   value2_rlm             meaning bor
# 50004      CV-CV-CV-CV     bVCVCVlV  сохранять_195807.0
# 50005      CV-CV-CV-CV     bVCVCVCV   сочиться_195859.0
# 50006  CV-CV-CV-CVC-CV  bVCVlVrVCCV   сочиться_195859.0
# 50007            CV-CV         bVCV   сочиться_195859.0
# 50008           CVC-CV        bVClV   сочиться_195859.0
# 50009         CV-CV-CV       bVCVCV   сочиться_195859.0

# %%
# ф-ия принимает на вход один согласный и базу данных
# сохраняет статистику по звуковым сочетаниям этого гласного в разных языках

def concrete_cons_statistics(consonant, df):
    # выбираем строки, где хотя бы для одного языка есть звук consonant
    cons_df = df[df[['value1_rlm','value2_rlm']].apply(lambda x: x.str.contains(consonant)).any(axis=1)]
    cons_df = cons_df[['language1', 'value1_rlm', 'language2', 'value2_rlm']]
    cons_df['operations'] = ''

    cons_df = cons_df[cons_df.notna().sum(axis=1) > 1]

    # возможные варианты звукосочетаний: последние два подразумевают, что транскрипция оканчивается согласным consonant
    sequence_list = [f'V{consonant}V', f'V{consonant}C', f'C{consonant}V', f'V{consonant}']

    # сохраняем в cons_dict для каждого языка сколько раз каждое звукосочетание в нем встретилось
    for index, row in cons_df.iterrows():
        l1, l2 = row[1], row[3]
        operations = row[4]
        operations_list = []
        for i, seq in enumerate(sequence_list):
            if i < 3:
                if seq in l1 and not(seq in l2):
                    if l1.endswith(f'V{consonant}V'):
                        break
                    if i == 0 and not('VV' in l2):
                        operations_list.append(f'{seq} // V')
                    else:
                        operations_list.append(f'{seq} // {seq[0] + seq[-1]}')
                    l1 = l1[l1.find(consonant):]
                elif seq in l2 and not(seq in l1):
                    if l2.endswith(f'V{consonant}V'):
                        break
                    if i == 0 and not('VV' in l1):
                        operations_list.append(f'V // {seq}')
                    else:
                        operations_list.append(f'{seq[0] + seq[-1]} // {seq}')
                    l2 = l2[l2.find(consonant):]
            else:
                if l1.endswith(seq.format(consonant)) and not(l2.endswith(seq.format(consonant))):
                    if l2.endswith(seq.format(consonant)+'V'):
                        operations_list.append(f'ends with {seq} // {seq}V')
                    else:
                        operations_list.append(f'ends with {seq} // {seq[0]}')
                elif l2.endswith(seq.format(consonant)) and not(l1.endswith(seq.format(consonant))):
                    if l1.endswith(seq.format(consonant)+'V'):
                        operations_list.append(f'ends with {seq}V // {seq}')
                    else:
                        operations_list.append(f'ends with {seq[0]} // {seq}')
        if operations_list:
            cons_df.at[index, 'operations'] = operations_list[0]
            for op in operations_list[1:]:
                new_row = row.copy()
                new_row['operations'] = op
                cons_df = pd.concat([cons_df.loc[:index], new_row.to_frame().T, cons_df.loc[index:]]).reset_index(drop=True)
    return cons_df

# %%
directory = 'output_html/sounds/'
os.makedirs(directory, exist_ok=True)

consonants_in_question = ['r', 'l', 'm', 'n', 'w', 'j', 'b']

for consonant in consonants_in_question:
    cons_df = concrete_cons_statistics(consonant, pairwise_comparison_df)
    cons_df = cons_df[cons_df['operations'] != '']
    cons_stats = cons_df.groupby(['language1', 'language2'])['operations'].value_counts().unstack(fill_value=0)
    to_html = cons_stats.to_html()
    with open(f'output_html/sounds/sound_{consonant}.html', 'w') as f:
        f.write(to_html)
# Out:
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# ...
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l1, l2 = row[1], row[3]
# /var/folders/p1/5mcjdkjd61s48x08bf18pn400000gn/T/ipykernel_28447/2258156243.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   operations = row[4]

# %%
# далее мы будем искать с помощью расстояния левенштейна характерные изменения для пар языков
# для использования ф-ии определения расстояния левенштейна для двух cv-ccv представлений, заменим слоги на буквы

syl_dict = {}

for index, row in pairwise_comparison_df[['value1_cv', 'value2_cv']].iterrows():
    for i in range(2):
        for el in row[i].split('-'):
            if el in syl_dict:
                syl_dict[el] += 1
            else:
                syl_dict[el] = 1
dict(sorted(syl_dict.items(), key=lambda x: x[1], reverse=True))

# %%
s2l = {'CV': 'a',
       'CVC': 'b',
       'V': 'c',
       'CCV': 'd',
       'VC': 'e',
       'CCVC': 'f',
       'CVCC': 'g',
       'CCCVC': 'h',
       'CCVCC': 'i',
       'VCC': 'j',
       'CCCV': 'k',
       'CVCCC': 'l',
       'CCCVCC': 'm',
       'CCCCVCCC': 'n',
       'VCCC': 'o',
       'CCVCCC': 'p',
       'CCCCCC': 'q',
       'CC': 'r'
      }

def syl_to_let(s, s2l):
    res = ''
    for el in s.split('-'):
        res += s2l[el]
    return res

def let_to_syl(s, s2l):
    res = next(key for key, value in s2l.items() if value == s)
    return res

# %%
def levenstein(str1, str2, flag):
    len_str1 = len(str1)
    len_str2 = len(str2)

    end_change, beg_change = '', ''
    
    matrix = [[0 for _ in range(len_str2 + 1)] for _ in range(len_str1 + 1)]
    
    for i in range(len_str1 + 1):
        matrix[i][0] = i
    for j in range(len_str2 + 1):
        matrix[0][j] = j
    
    for i in range(1, len_str1 + 1):
        for j in range(1, len_str2 + 1):
            cost = 0 if str1[i - 1] == str2[j - 1] else 1
            matrix[i][j] = min(matrix[i-1][j] + 1, matrix[i][j-1] + 1, matrix[i-1][j-1] + cost)
    
    operations = []
    i, j = len_str1, len_str2
    while i > 0 or j > 0:
        if i > 0 and matrix[i][j] == matrix[i-1][j] + 1:
            # Если флаг true, меняем обратно буквы на слоги
            if flag:
                operations.append(f"Delete {let_to_syl(str1[i-1], s2l)} from position {i-1}")
            else:
                operations.append(f"Delete '{str1[i-1]}' from position {i-1}")
            i -= 1
        elif j > 0 and matrix[i][j] == matrix[i][j-1] + 1:
            if flag:
                operations.append(f"Insert {let_to_syl(str2[j-1], s2l)} at position {i}")
            else:
                operations.append(f"Insert '{str2[j-1]}' at position {i}")
            j -= 1
        else:
            if matrix[i][j] != matrix[i-1][j-1]:
                if flag:
                    operations.append(f"Replace {let_to_syl(str1[i-1], s2l)} with {let_to_syl(str2[j-1], s2l)} at position {i-1}")
                else:
                    operations.append(f"Replace '{str1[i-1]}' with '{str2[j-1]}' at position {i-1}")
            i -= 1
            j -= 1
    
    operations.reverse()
    if operations != [] and 'position 0' in operations[0]:
        beg_change = 1
    if operations != [] and (f'position {len_str1 - 1}' in operations[-1] or f'position {len_str2 - 1}' in operations[-1]):
        end_change = 1

    return matrix[len_str1][len_str2], operations, end_change, beg_change

# %%
pairwise_comparison_df['cv_lev'] = pairwise_comparison_df.apply(lambda row: levenstein(syl_to_let(row['value1_cv'], s2l), syl_to_let(row['value2_cv'], s2l), False)[0], axis=1)
pairwise_comparison_df['cv_operations'] = pairwise_comparison_df.apply(lambda row: '\n'.join(levenstein(syl_to_let(row['value1_cv'], s2l), syl_to_let(row['value2_cv'], s2l), True)[1]), axis=1)
pairwise_comparison_df['end_change'] = pairwise_comparison_df.apply(lambda row: levenstein(syl_to_let(row['value1_cv'], s2l), syl_to_let(row['value2_cv'], s2l), True)[2], axis=1)
pairwise_comparison_df['beg_change'] = pairwise_comparison_df.apply(lambda row: levenstein(syl_to_let(row['value1_cv'], s2l), syl_to_let(row['value2_cv'], s2l), True)[3], axis=1)

# pairwise_comparison_df['lemma_lev'] = pairwise_comparison_df.apply(lambda row: levenstein(row['value1'], row['value2'], False)[0], axis=1)
# pairwise_comparison_df['lemma_operations'] = pairwise_comparison_df.apply(lambda row: '\n'.join(levenstein(row['value1'], row['value2'], False)[1]), axis=1)

# %%
pairwise_comparison_df

# %%
pairwise_comparison_df.to_csv('pairwise_comparison.csv', index=False)

# %%
end_change_df = pairwise_comparison_df[(pairwise_comparison_df['cv_lev'] == 1) & (pairwise_comparison_df['bor'] == '') & (pairwise_comparison_df['end_change'] == 1)]
end_change_df['cv_operations'] = end_change_df['cv_operations'].apply(lambda x: x.split('at')[0])
end_change_df['cv_operations'] = end_change_df['cv_operations'].apply(lambda x: x.split('from')[0])

beg_change_df = pairwise_comparison_df[(pairwise_comparison_df['cv_lev'] == 1) &(pairwise_comparison_df['bor'] == '') & (pairwise_comparison_df['beg_change'] == 1)]
beg_change_df['cv_operations'] = beg_change_df['cv_operations'].apply(lambda x: x.split('at')[0])
beg_change_df['cv_operations'] = beg_change_df['cv_operations'].apply(lambda x: x.split('from')[0])

# %%
end_stats = end_change_df.groupby(['language1', 'language2'])['cv_operations'].value_counts().unstack(fill_value=0)
end_column_totals = end_stats.sum()
end_stats_sorted = end_stats[end_column_totals.sort_values(ascending=False).index]
end_stats_sorted

# %%
directory = 'output_html/pairwise_data/'
os.makedirs(directory, exist_ok=True)

html_end = end_stats_sorted.to_html()
with open('output_html/pairwise_data/end_stats.html', 'w') as f:
    f.write(html_end)

# %%
beg_stats = beg_change_df.groupby(['language1', 'language2'])['cv_operations'].value_counts().unstack(fill_value=0)
beg_column_totals = beg_stats.sum()
beg_stats_sorted = beg_stats[beg_column_totals.sort_values(ascending=False).index]
beg_stats_sorted

# %%
html_beg = beg_stats_sorted.to_html()
with open('output_html/pairwise_data/beg_stats.html', 'w') as f:
    f.write(html_beg)

# %%
end_stats_df = end_change_df.groupby(['language1', 'language2']).apply(lambda x: x.sort_values(by='cv_operations'))[['cv_operations', 'value1', 'value1_cv', 'value2', 'value2_cv']].reset_index()
end_stats_df.to_csv('end_change.csv', index=False)

beg_stats_df = beg_change_df.groupby(['language1', 'language2']).apply(lambda x: x.sort_values(by='cv_operations'))[['cv_operations', 'value1', 'value1_cv', 'value2', 'value2_cv']].reset_index()
beg_stats_df.to_csv('beg_change.csv', index=False)

# %%
# !jupyter nbconvert --to html data_analyse.ipynb
